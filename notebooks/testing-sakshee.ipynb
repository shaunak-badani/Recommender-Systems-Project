# %%
import os
import pandas as pd
import numpy as np

# %%
base_path = '../data'
business_path = os.path.join(base_path, 'yelp_academic_dataset_business.json')
review_path = os.path.join(base_path, 'yelp_academic_dataset_review.json')
user_path = os.path.join(base_path, 'yelp_academic_dataset_user.json')
photos_path = os.path.join(base_path, 'filtered_photos.json')

# %%
users_df = pd.read_json(user_path, lines=True)

# %%
business_df = pd.read_json(business_path, lines=True)
business_df.head()
# Out:
#               business_id                      name  \
# 0  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 1  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 2  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# 3  CF33F8-E6oudUQ46HnavjQ            Sonic Drive-In
# 4  qkRM_2X51Yqxk3btlwAQIg            Temple Beth-El
#
#                            address            city state postal_code  \
# 0  87 Grasso Plaza Shopping Center          Affton    MO       63123
# 1                      935 Race St    Philadelphia    PA       19107
# 2                    101 Walnut St      Green Lane    PA       18054
# 3                    615 S Main St    Ashland City    TN       37015
# 4               400 Pasadena Ave S  St. Petersburg    FL       33707
#
#     latitude  longitude  stars  review_count  is_open  \
# 0  38.551126 -90.335695    3.0            15        1
# 1  39.955505 -75.155564    4.0            80        1
# 2  40.338183 -75.471659    4.5            13        1
# 3  36.269593 -87.058943    2.0             6        1
# 4  27.766590 -82.732983    3.5             5        1
#
#                                           attributes  \
# 0             {'BusinessAcceptsCreditCards': 'True'}
# 1  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 2  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
# 3  {'BusinessParking': 'None', 'BusinessAcceptsCr...
# 4                                               None
#
#                                           categories  \
# 0  Shipping Centers, Local Services, Notaries, Ma...
# 1  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 2                          Brewpubs, Breweries, Food
# 3  Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 4                Synagogues, Religious Organizations
#
#                                                hours
# 0  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 1  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 2  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...
# 3  {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...
# 4  {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...

# %%
for i, row in business_df.iterrows():
    attrs = row['attributes']
    if attrs is not None:
        for key, value in attrs.items():
            print(key,value)

    if i > 10:
        break
# Out:
# BusinessAcceptsCreditCards True
# RestaurantsDelivery False
# OutdoorSeating False
# BusinessAcceptsCreditCards False
# BusinessParking {'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}
# BikeParking True
# RestaurantsPriceRange2 1
# RestaurantsTakeOut True
# ByAppointmentOnly False
# WiFi u'free'
# Alcohol u'none'
# Caters True
# BusinessAcceptsCreditCards True
# WheelchairAccessible True
# RestaurantsTakeOut True
# BusinessParking {'garage': None, 'street': None, 'validated': None, 'lot': True, 'valet': False}
# BikeParking True
# GoodForKids True
# Caters False
# BusinessParking None
# BusinessAcceptsCreditCards True
# RestaurantsAttire u'casual'
# OutdoorSeating True
# RestaurantsReservations False
# Caters False
# RestaurantsTakeOut True
# Alcohol u'none'
# Ambience None
# GoodForKids True
# RestaurantsPriceRange2 1
# ByAppointmentOnly False
# CoatCheck False
# DogsAllowed False
# RestaurantsTableService False
# RestaurantsGoodForGroups True
# RestaurantsDelivery True
# WiFi u'no'
# WheelchairAccessible True
# HasTV True
# HappyHour False
# DriveThru True
# BikeParking False
# RestaurantsAttire 'casual'
# RestaurantsGoodForGroups False
# BusinessAcceptsCreditCards True
# OutdoorSeating True
# GoodForKids True
# Alcohol u'none'
# BusinessParking {'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}
# DogsAllowed False
# RestaurantsTableService False
# ByAppointmentOnly False
# WiFi u'no'
# RestaurantsPriceRange2 1
# RestaurantsReservations False
# HasTV True
# RestaurantsDelivery True
# CoatCheck False
# Caters False
# RestaurantsTakeOut True
# DriveThru True
# HappyHour False
# WheelchairAccessible True
# RestaurantsPriceRange2 2
# BikeParking True
# BusinessAcceptsCreditCards True
# BusinessParking {'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}
# Alcohol 'none'
# OutdoorSeating None
# RestaurantsReservations False
# Ambience {'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': False, 'upscale': False, 'classy': False, 'casual': False}
# GoodForMeal {'dessert': False, 'latenight': False, 'lunch': False, 'dinner': False, 'brunch': False, 'breakfast': False}
# BusinessParking {'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}
# RestaurantsReservations False
# RestaurantsTakeOut True
# RestaurantsAttire 'casual'
# GoodForKids True
# BikeParking False
# RestaurantsPriceRange2 1
# BusinessAcceptsCreditCards True
# GoodForMeal {'dessert': False, 'latenight': False, 'lunch': False, 'dinner': False, 'brunch': False, 'breakfast': False}
# RestaurantsGoodForGroups True
# OutdoorSeating False
# WiFi u'no'
# Alcohol 'none'
# RestaurantsDelivery True
# BusinessParking {'garage': None, 'street': False, 'validated': None, 'lot': True, 'valet': False}
# HasTV True
# Ambience {'touristy': None, 'hipster': None, 'romantic': False, 'divey': None, 'intimate': None, 'trendy': None, 'upscale': None, 'classy': None, 'casual': True}
# RestaurantsReservations True
# RestaurantsGoodForGroups True
# RestaurantsAttire 'casual'
# BusinessAcceptsCreditCards True
# WiFi 'free'
# HasTV False
# RestaurantsTakeOut True
# Ambience {'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': False, 'upscale': False, 'classy': True, 'casual': False}
# GoodForKids False
# GoodForMeal {'dessert': True, 'latenight': None, 'lunch': None, 'dinner': True, 'brunch': None, 'breakfast': None}
# NoiseLevel u'average'
# RestaurantsPriceRange2 2
# Alcohol 'full_bar'
# DogsAllowed False
# HappyHour True
# RestaurantsDelivery True
# WheelchairAccessible True
# OutdoorSeating True
# RestaurantsTableService True
# BusinessParking {u'valet': False, u'garage': None, u'street': True, u'lot': False, u'validated': None}
# DriveThru False
# BusinessAcceptsCreditCards True
# WiFi u'free'
# ByAppointmentOnly False

# %%
# Now let's check unique values for interesting fields
for attr in [
        'BusinessAcceptsCreditCards', 'RestaurantsTakeOut', 'RestaurantsDelivery',
        'OutdoorSeating', 'WiFi', 'Alcohol', 'NoiseLevel', 'RestaurantsGoodForGroups',
        'RestaurantsReservations', 'RestaurantsPriceRange2'
    ]:
    values = business_df['attributes'].apply(lambda x: x.get(attr, 'unknown')).unique()
    print(f"{attr}: {values}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 7
#       1 # Now let's check unique values for interesting fields
#       2 for attr in [
#       3         'BusinessAcceptsCreditCards', 'RestaurantsTakeOut', 'RestaurantsDelivery',
#       4         'OutdoorSeating', 'WiFi', 'Alcohol', 'NoiseLevel', 'RestaurantsGoodForGroups',
#       5         'RestaurantsReservations', 'RestaurantsPriceRange2'
#       6     ]:
# ----> 7     values = business_df['attributes'].apply(lambda x: x.get(attr, 'unknown')).unique()
#       8     print(f"{attr}: {values}")
#
# File c:\Users\saksh\OneDrive\Documents\Duke Academics\Spring 2025\Deep Learning\Recommendation-Systems-Project\backend\.venv\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)   4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)   4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\saksh\OneDrive\Documents\Duke Academics\Spring 2025\Deep Learning\Recommendation-Systems-Project\backend\.venv\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\saksh\OneDrive\Documents\Duke Academics\Spring 2025\Deep Learning\Recommendation-Systems-Project\backend\.venv\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\saksh\OneDrive\Documents\Duke Academics\Spring 2025\Deep Learning\Recommendation-Systems-Project\backend\.venv\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\saksh\OneDrive\Documents\Duke Academics\Spring 2025\Deep Learning\Recommendation-Systems-Project\backend\.venv\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[44], line 7, in <lambda>(x)
#       1 # Now let's check unique values for interesting fields
#       2 for attr in [
#       3         'BusinessAcceptsCreditCards', 'RestaurantsTakeOut', 'RestaurantsDelivery',
#       4         'OutdoorSeating', 'WiFi', 'Alcohol', 'NoiseLevel', 'RestaurantsGoodForGroups',
#       5         'RestaurantsReservations', 'RestaurantsPriceRange2'
#       6     ]:
# ----> 7     values = business_df['attributes'].apply(lambda x: x.get(attr, 'unknown')).unique()
#       8     print(f"{attr}: {values}")
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
review_df = pd.read_json(review_path, lines=True)

# %%
def enhance_user_features(users_df):
    users_df = users_df.copy()

    # Rename columns for consistency
    users_df.rename(columns={
        'name': 'user_name',
        'review_count': 'user_review_count'
    }, inplace=True)

    # Parse datetime
    users_df['yelping_since'] = pd.to_datetime(users_df['yelping_since'])
    users_df['yelping_years'] = (pd.to_datetime('now') - users_df['yelping_since']).dt.days / 365.0
    users_df['yelping_years'] = users_df['yelping_years'].fillna(0)

    # Core engagement
    users_df['reviews_per_year'] = users_df['user_review_count'] / (users_df['yelping_years'] + 1)
    users_df['engagement_score'] = (users_df['useful'] + users_df['funny'] + users_df['cool'] + users_df['fans']) / (users_df['yelping_years'] + 1)
    users_df['engagement_per_review'] = (users_df['useful'] + users_df['funny'] + users_df['cool']) / (users_df['user_review_count'] + 1)

    # Compliments
    compliment_cols = [col for col in users_df.columns if col.startswith('compliment_')]
    users_df['total_compliments'] = users_df[compliment_cols].sum(axis=1)
    users_df['compliments_per_review'] = users_df['total_compliments'] / (users_df['user_review_count'] + 1)
    users_df['compliment_type_count'] = users_df[compliment_cols].astype(bool).sum(axis=1)

    # Social metrics
    users_df['num_friends'] = users_df['friends'].fillna('').apply(lambda x: len(x.split(',')) if x else 0)
    users_df['friend_density'] = users_df['num_friends'] / (users_df['yelping_years'] + 1)
    users_df['friend_to_fan_ratio'] = users_df['num_friends'] / (users_df['fans'] + 1)

    # Elite years
    users_df['elite_years_count'] = users_df['elite'].fillna('').apply(lambda x: len(x.split(',')) if x else 0)
    users_df['is_elite'] = users_df['elite'].apply(lambda x: 0 if x == '' else 1)
    users_df['elite_score'] = np.log1p(users_df['elite_years_count'])

    # Rating behavior
    users_df['tough_reviewer'] = (users_df['average_stars'] < 3.0).astype(int)

    # Grouped compliments
    social_comps = ['compliment_cool', 'compliment_funny', 'compliment_photos']
    thoughtful_comps = ['compliment_note', 'compliment_writer', 'compliment_plain']
    users_df['social_compliments'] = users_df[social_comps].sum(axis=1)
    users_df['thoughtful_compliments'] = users_df[thoughtful_comps].sum(axis=1)

    # Drop columns that won't be used directly
    drop_cols = ['friends', 'elite', 'yelping_since', 'cool', 'funny', 'useful', 'fans', 'average_stars', 'compliment_hot', 'compliment_list', 'compliment_note', 'compliment_writer', 'compliment_photos', 'compliment_plain', 'compliment_cool', 'compliment_funny', 'compliment_hot', 'compliment_list', 'compliment_note', 'compliment_writer', 'compliment_photos', 'compliment_plain', 'compliment_more', 'compliment_profile', 'compliment_cute']
    users_df.drop(columns=drop_cols, inplace=True)

    return users_df

# %%
users_df = enhance_user_features(users_df)
users_df.head()
# Out:
#                   user_id user_name  user_review_count  yelping_years  \
# 0  qVc8ODYU5SZjKXVBgXdI7w    Walker                585      18.224658
# 1  j14WgRoU_-2ZE1aw1dXrJg    Daniel               4333      16.221918
# 2  hA5lMy-EnncsH4JoR-hFGQ     Karen                 79      18.276712
# 3  E9kcWJdJUHuTKfQurPljwA      Mike                358      16.342466
# 4  4ZaqBJqt7laPPs8xfWvr6A      Nina                801      16.663014
#
#    reviews_per_year  engagement_score  engagement_per_review  \
# 0         30.429671        766.567621              24.692833
# 1        251.597996       5027.082405              19.251961
# 2          4.098209          2.697555               0.637500
# 3         20.642970         38.460506               1.793872
# 4         45.349000        190.907399               4.110973
#
#    total_compliments  compliments_per_review  compliment_type_count  \
# 0               2873                4.902730                     11
# 1              20631                4.760268                     11
# 2                  4                0.050000                      4
# 3                 56                0.155989                      8
# 4                306                0.381546                     10
#
#    num_friends  friend_density  friend_to_fan_ratio  elite_years_count  \
# 0        14995      779.987887            55.951493                  1
# 1         4646      269.772510             1.480089                 14
# 2           27        1.400654            13.500000                  0
# 3           82        4.728278             3.416667                  0
# 4          492       27.854816             6.473684                 13
#
#    is_elite  elite_score  tough_reviewer  social_compliments  \
# 0         1     0.693147               0                1114
# 1         1     2.708050               0                8208
# 2         0     0.000000               0                   0
# 3         0     0.000000               0                  24
# 4         1     2.639057               0                 102
#
#    thoughtful_compliments
# 0                    1315
# 1                   10422
# 2                       2
# 3                      19
# 4                     164

# %%
users_df.columns
# Out:
# Index(['user_id', 'user_name', 'user_review_count', 'yelping_years',
#        'reviews_per_year', 'engagement_score', 'engagement_per_review',
#        'total_compliments', 'compliments_per_review', 'compliment_type_count',
#        'num_friends', 'friend_density', 'friend_to_fan_ratio',
#        'elite_years_count', 'is_elite', 'elite_score', 'tough_reviewer',
#        'social_compliments', 'thoughtful_compliments'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import ast
from datetime import datetime

# Fix time string formatting
def fix_time(t):
    parts = t.split(':')
    return f"{int(parts[0]):02d}:{int(parts[1]):02d}"

# Safely parse dictionary-like strings
def safe_parse_dict(s):
    if isinstance(s, dict):
        return s
    if isinstance(s, str):
        try:
            return ast.literal_eval(s)
        except:
            return {}
    return {}

# Extract hour features
def extract_hour_features(hours_str):
    hours_dict = safe_parse_dict(hours_str)
    total_minutes = 0
    open_weekends = 0
    open_late = 0
    days_open = 0

    for day, time_str in hours_dict.items():
        try:
            open_time, close_time = time_str.split('-')
            open_dt = datetime.strptime(fix_time(open_time), "%H:%M")
            close_dt = datetime.strptime(fix_time(close_time), "%H:%M")

            # Handle overnight hours
            if close_dt <= open_dt:
                duration = (24 - open_dt.hour + close_dt.hour) * 60 + (close_dt.minute - open_dt.minute)
            else:
                duration = (close_dt.hour - open_dt.hour) * 60 + (close_dt.minute - open_dt.minute)

            total_minutes += duration
            days_open += 1

            if close_dt.hour >= 22:
                open_late = 1
            if day in ['Saturday', 'Sunday']:
                open_weekends = 1

        except Exception as e:
            continue

    return pd.Series({
        'weekly_hours': round(total_minutes / 60, 1),
        'open_weekends': open_weekends,
        'open_late': open_late,
        'days_open': days_open
    })

# Preprocessing pipeline
def business_data_preprocessing(business_df, top_n_categories=20):

    # Filter for open restaurants
    business_df = business_df[
        business_df['categories'].apply(lambda x: isinstance(x, str) and 'Restaurants' in x)
    ]
    business_df = business_df[business_df['is_open'] == 1].copy()

    # Rename
    business_df.rename(columns={
        'stars': 'rating',
        'review_count': 'business_review_count',
        'name': 'business_name'
    }, inplace=True)

    # Log popularity, binary rating
    business_df['popularity'] = np.log1p(business_df['business_review_count'])
    business_df['high_rating'] = (business_df['rating'] >= 4).astype(int)

    # Parse attributes safely
    curated_attributes = [
        'BusinessAcceptsCreditCards', 'RestaurantsTakeOut', 'RestaurantsDelivery',
        'OutdoorSeating', 'ByAppointmentOnly', 'Caters', 'RestaurantsGoodForGroups',
        'RestaurantsReservations', 'RestaurantsPriceRange2', 'BikeParking', 'WheelchairAccessible', 'GoodForKids', 'DogsAllowed', 'HasTV', 'HappyHour', 'DriveThru'
    ]

    def extract_attribute(attr_str, key):
        attr_dict = safe_parse_dict(attr_str)
        val = attr_dict.get(key)

        if val == 'True' or val is True:
            return 1
        elif val == 'False' or val is False:
            return 0
        else:
            return -1  # unknown or missing


    for attr in curated_attributes:
        business_df[f'attr_{attr.lower()}'] = business_df['attributes'].apply(lambda x: extract_attribute(x, attr))

    # Category processing
    business_df['category_list'] = business_df['categories'].apply(lambda x: [c.strip() for c in x.split(',')])
    all_categories = business_df['category_list'].explode()
    top_categories = all_categories.value_counts().head(top_n_categories).index.tolist()

    cat_df = pd.DataFrame()
    for cat in top_categories:
        col_name = f"cat_{cat.lower().replace(' ', '_')}"
        cat_df[col_name] = business_df['category_list'].apply(lambda x: int(cat in x))

    # Extract hour features
    hour_features = business_df['hours'].apply(extract_hour_features)

    # Final dataframe
    final_df = pd.concat([
        business_df.drop(columns=[
            'attributes', 'categories', 'category_list',
            'address', 'city', 'state', 'postal_code',
            'latitude', 'longitude', 'hours'
        ]),
        cat_df,
        hour_features
    ], axis=1)

    return final_df

# %%
business_df = business_data_preprocessing(business_df)
business_df.head()
# Out:
#               business_id          business_name  rating  \
# 1  MTSW4McQd7CbVtyjqoe9mw     St Honore Pastries     4.0
# 3  CF33F8-E6oudUQ46HnavjQ         Sonic Drive-In     2.0
# 5  bBDDEgkFA1Otx9Lfe7BZUQ         Sonic Drive-In     1.5
# 7  eEOYSgkmpB90uNA7lDOMRA  Vietnamese Food Truck     4.0
# 8  il_Ro8jwPlHresjw9EGmBg                Denny's     2.5
#
#    business_review_count  is_open  popularity  high_rating  \
# 1                     80        1    4.394449            1
# 3                      6        1    1.945910            0
# 5                     10        1    2.397895            0
# 7                     10        1    2.397895            1
# 8                     28        1    3.367296            0
#
#    attr_businessacceptscreditcards  attr_restaurantstakeout  \
# 1                                0                        1
# 3                                1                        1
# 5                                1                        1
# 7                               -1                       -1
# 8                                1                        1
#
#    attr_restaurantsdelivery  ...  cat_seafood  cat_salad  cat_chicken_wings  \
# 1                         0  ...            0          0                  0
# 3                         1  ...            0          0                  0
# 5                         1  ...            0          0                  0
# 7                        -1  ...            0          0                  0
# 8                         1  ...            0          0                  0
#
#    cat_event_planning_&_services  cat_chinese  cat_cafes  weekly_hours  \
# 1                              0            0          0          94.0
# 3                              0            0          0         114.0
# 5                              0            0          0         100.0
# 7                              0            0          0          23.0
# 8                              0            0          0         112.0
#
#    open_weekends  open_late  days_open
# 1            1.0        0.0        7.0
# 3            1.0        1.0        7.0
# 5            1.0        0.0        7.0
# 7            1.0        0.0        7.0
# 8            1.0        1.0        7.0
#
# [5 rows x 47 columns]

# %%
business_df.columns
# Out:
# Index(['business_id', 'business_name', 'rating', 'business_review_count',
#        'is_open', 'hours', 'popularity', 'high_rating',
#        'attr_businessacceptscreditcards', 'attr_restaurantstakeout',
#        'attr_restaurantsdelivery', 'attr_outdoorseating', 'attr_wifi',
#        'attr_alcohol', 'attr_noiselevel', 'attr_restaurantsgoodforgroups',
#        'attr_restaurantsreservations', 'attr_restaurantspricerange2',
#        'cat_restaurants', 'cat_food', 'cat_nightlife', 'cat_sandwiches',
#        'cat_bars', 'cat_american_(traditional)', 'cat_fast_food', 'cat_pizza',
#        'cat_breakfast_&_brunch', 'cat_burgers', 'cat_american_(new)',
#        'cat_mexican', 'cat_italian', 'cat_coffee_&_tea', 'cat_seafood',
#        'cat_salad', 'cat_chicken_wings', 'cat_event_planning_&_services',
#        'cat_chinese', 'cat_cafes'],
#       dtype='object')

# %%
all_categories = []
for i, row in business_df.iterrows():
    if row['categories'] is not None:
        current_categories = row['categories'].split(', ')
        for category in current_categories:
            all_categories.append(category)

all_categories
# Out:
# ['Shipping Centers',
#  'Local Services',
#  'Notaries',
#  'Mailbox Centers',
#  'Printing Services',
#  'Restaurants',
#  'Food',
#  'Bubble Tea',
#  'Coffee & Tea',
#  'Bakeries',
#  'Brewpubs',
#  'Breweries',
#  'Food',
#  'Burgers',
#  'Fast Food',
#  'Sandwiches',
#  'Food',
#  'Ice Cream & Frozen Yogurt',
#  'Restaurants',
#  'Synagogues',
#  'Religious Organizations',
#  'Ice Cream & Frozen Yogurt',
#  'Fast Food',
#  'Burgers',
#  'Restaurants',
#  'Food',
#  'Department Stores',
#  'Shopping',
#  'Fashion',
#  'Vietnamese',
#  'Food',
#  'Restaurants',
#  'Food Trucks',
#  'American (Traditional)',
#  'Restaurants',
#  'Diners',
#  'Breakfast & Brunch',
#  'Sushi Bars',
#  'Restaurants',
#  'Japanese',
#  'Automotive',
#  'Auto Parts & Supplies',
#  'Auto Customization',
#  'Automotive',
#  'Car Rental',
#  'Hotels & Travel',
#  'Truck Rental',
#  'Korean',
#  'Restaurants',
#  'Shopping',
#  'Books',
#  'Mags',
#  'Music & Video',
#  'Bookstores',
#  'Steakhouses',
#  'Asian Fusion',
#  'Restaurants',
#  'Restaurants',
#  'Italian',
#  'Pizza',
#  'Chicken Wings',
#  'Sandwiches',
#  'Restaurants',
#  'Trampoline Parks',
#  'Active Life',
#  'Pizza',
#  'Restaurants',
#  'Event Planning & Services',
#  'Hotels',
#  'Hotels & Travel',
#  'Eatertainment',
#  'Arts & Entertainment',
#  'Brewpubs',
#  'American (Traditional)',
#  'Bakeries',
#  'Breweries',
#  'Food',
#  'Restaurants',
#  'Hair Salons',
#  'Hair Extensions',
#  'Beauty & Spas',
#  'Wigs',
#  'Shopping',
#  'Restaurants',
#  'Specialty Food',
#  'Steakhouses',
#  'Food',
#  'Italian',
#  'Pizza',
#  'Pasta Shops',
#  'Health & Medical',
#  'Beauty & Spas',
#  'Laser Hair Removal',
#  'Doctors',
#  'Hair Removal',
#  'Chiropractors',
#  'Weight Loss Centers',
#  'Sports Medicine',
#  'Medical Spas',
#  'Skin Care',
#  'Restaurants',
#  'Italian',
#  'Food',
#  'Grocery',
#  'Convenience Stores',
#  'Hotels',
#  'Hotels & Travel',
#  'Event Planning & Services',
#  'Vitamins & Supplements',
#  'Ice Cream & Frozen Yogurt',
#  'Food',
#  'Juice Bars & Smoothies',
#  'Shopping',
#  'Sports Bars',
#  'American (New)',
#  'American (Traditional)',
#  'Nightlife',
#  'Bars',
#  'Restaurants',
#  'Uniforms',
#  'Shopping',
#  'Hotels & Travel',
#  'Tours',
#  'Local Flavor',
#  'Local Services',
#  'Appliances & Repair',
#  'Chocolatiers & Shops',
#  'Specialty Food',
#  'Candy Stores',
#  'Food',
#  'Food Trucks',
#  'Food',
#  'Shopping',
#  'Baby Gear & Furniture',
#  'Home Decor',
#  'Furniture Stores',
#  'Home & Garden',
#  'Banks & Credit Unions',
#  'Financial Services',
#  'American (Traditional)',
#  'Bars',
#  'Nightlife',
#  'Sports Bars',
#  'Restaurants',
#  'Health & Medical',
#  'Personal Care Services',
#  'Beauty & Spas',
#  'Massage',
#  'Nail Salons',
#  'American (Traditional)',
#  'Sports Bars',
#  'Restaurants',
#  'Bars',
#  'Nightlife',
#  'Steakhouses',
#  'Salad',
#  'Beer Bar',
#  'Burgers',
#  'Sports Bars',
#  'Bars',
#  'Lounges',
#  'Restaurants',
#  'Salad',
#  'Wraps',
#  'Nightlife',
#  'American (New)',
#  'Food',
#  'Beer',
#  'Wine & Spirits',
#  'Breweries',
#  'Restaurants',
#  'Automotive',
#  'Delis',
#  'Gas Stations',
#  'Food',
#  'Coffee & Tea',
#  'Sandwiches',
#  'Convenience Stores',
#  'Keys & Locksmiths',
#  'Home Services',
#  'Local Services',
#  'Food',
#  'Restaurants',
#  'Salad',
#  'Coffee & Tea',
#  'Breakfast & Brunch',
#  'Sandwiches',
#  'Bakeries',
#  'Pet Groomers',
#  'Pet Sitting',
#  'Pets',
#  'Pet Services',
#  'Nightlife',
#  'Pubs',
#  'Event Planning & Services',
#  'Wine Bars',
#  'Bars',
#  'Gastropubs',
#  'Restaurants',
#  'Venues & Event Spaces',
#  'Ice Cream & Frozen Yogurt',
#  'Coffee & Tea',
#  'Restaurants',
#  'Sandwiches',
#  'Food',
#  'Home Decor',
#  'Shopping',
#  'Antiques',
#  'Books',
#  'Mags',
#  'Music & Video',
#  'Home & Garden',
#  'Towing',
#  'Automotive',
#  'Body Shops',
#  'Real Estate',
#  'Home Services',
#  'Financial Services',
#  'Mortgage Brokers',
#  'Mortgage Lenders',
#  "Women's Clothing",
#  "Men's Clothing",
#  'Accessories',
#  'Fashion',
#  'Jewelry',
#  'Department Stores',
#  'Shopping',
#  'Shoe Stores',
#  'Seafood',
#  'Restaurants',
#  'Restaurants',
#  'Seafood',
#  'Cajun/Creole',
#  'Mexican',
#  'Restaurants',
#  'Printing Services',
#  'Local Services',
#  'Shipping Centers',
#  'Couriers & Delivery Services',
#  'Notaries',
#  'Restaurants',
#  'French',
#  'Moroccan',
#  'Seafood',
#  'Mediterranean',
#  'Flooring',
#  'Handyman',
#  'Contractors',
#  'Home Services',
#  'Bars',
#  'Lounges',
#  'American (New)',
#  'Restaurants',
#  'Nightlife',
#  'Wine Bars',
#  'Eyewear & Opticians',
#  'Health & Medical',
#  'Shopping',
#  'Doctors',
#  'Optometrists',
#  'Ophthalmologists',
#  'Bars',
#  'Beer Gardens',
#  'Food',
#  'Breweries',
#  'Nightlife',
#  'Tours',
#  'Pubs',
#  'Wine Tours',
#  'Beer Tours',
#  'Hotels & Travel',
#  'Grocery',
#  'Food',
#  'Shopping',
#  'Fashion',
#  'Drugstores',
#  'Department Stores',
#  'Discount Store',
#  'Electronics',
#  'Eyewear & Opticians',
#  'Shopping',
#  'Grocery',
#  'Food',
#  'Couriers & Delivery Services',
#  'Local Services',
#  'Food',
#  'Food Delivery Services',
#  'Parenting Classes',
#  'Maternity Wear',
#  'Fashion',
#  'Education',
#  'Specialty Schools',
#  'Local Services',
#  'Home Services',
#  'Laundry Services',
#  'Child Care & Day Care',
#  'Shopping',
#  'Baby Gear & Furniture',
#  'Sandwiches',
#  'Fast Food',
#  'Restaurants',
#  'Barbers',
#  'Beauty & Spas',
#  'Hardware Stores',
#  'Home Services',
#  'Hot Tub & Pool',
#  'Pool & Hot Tub Service',
#  'Home & Garden',
#  'Shopping',
#  'Nightlife',
#  'Chicken Wings',
#  'Pubs',
#  'Bars',
#  'American (Traditional)',
#  'Restaurants',
#  'Restaurants',
#  'Chinese',
#  'Bars',
#  'Restaurants',
#  'Sports Bars',
#  'Nightlife',
#  'Custom Cakes',
#  'Food',
#  'Desserts',
#  'Cupcakes',
#  'Ice Cream & Frozen Yogurt',
#  'Discount Store',
#  'Department Stores',
#  'Food',
#  'Drugstores',
#  'Shopping',
#  'Grocery',
#  'Fashion',
#  'Mobile Phones',
#  'Auto Repair',
#  'Automotive',
#  'Tires',
#  'Oil Change Stations',
#  'Pain Management',
#  'Doctors',
#  'Health & Medical',
#  'Osteopathic Physicians',
#  'Food',
#  'Organic Stores',
#  'Specialty Food',
#  'Health Markets',
#  'Grocery',
#  'Desserts',
#  'Do-It-Yourself Food',
#  'Food',
#  'Patisserie/Cake Shop',
#  'Live/Raw Food',
#  'Restaurants',
#  'Seafood',
#  'Beer Bar',
#  'Beer',
#  'Wine & Spirits',
#  'Bars',
#  'Food',
#  'Nightlife',
#  'Buses',
#  'Transportation',
#  'Bus Tours',
#  'Hotels & Travel',
#  'Travel Agents',
#  'Travel Services',
#  'Airport Shuttles',
#  'Tours',
#  'Public Transportation',
#  'Food',
#  'Desserts',
#  'Fashion',
#  'Shopping',
#  "Men's Clothing",
#  'Shopping',
#  'Books',
#  'Mags',
#  'Music & Video',
#  'Toy Stores',
#  'Hobby Shops',
#  'Comic Books',
#  'Painters',
#  'Home Services',
#  'Decks & Railing',
#  'Contractors',
#  'Pressure Washers',
#  'Hotels',
#  'Hotels & Travel',
#  'Bed & Breakfast',
#  'Event Planning & Services',
#  'Massage',
#  'Health & Medical',
#  'Medical Spas',
#  'Beauty & Spas',
#  'Banks & Credit Unions',
#  'Financial Services',
#  'Nightlife',
#  'Restaurants',
#  'Bars',
#  'Mexican',
#  'Body Shops',
#  'Automotive',
#  'Burgers',
#  'Restaurants',
#  'Fast Food',
#  'Event Planning & Services',
#  'Caterers',
#  'Italian',
#  'Restaurants',
#  'Pharmacy',
#  'Health & Medical',
#  'Convenience Stores',
#  'Drugstores',
#  'Food',
#  'Shopping',
#  'Beauty & Spas',
#  'Tattoo',
#  'Oil Change Stations',
#  'Automotive',
#  'Tires',
#  'Auto Repair',
#  'Waxing',
#  'Hair Removal',
#  'Skin Care',
#  'Eyelash Service',
#  'Beauty & Spas',
#  'Active Life',
#  'Playgrounds',
#  'Parks',
#  'Swimming Pools',
#  'Health & Medical',
#  'Chiropractors',
#  'Beauty & Spas',
#  'Hair Stylists',
#  'Hair Extensions',
#  'Hair Salons',
#  'Dog Parks',
#  'Active Life',
#  'Parks',
#  'Venues & Event Spaces',
#  'Performing Arts',
#  'Arts & Entertainment',
#  'Hotels & Travel',
#  'Food',
#  'Convenience Stores',
#  'American (New)',
#  'Beauty & Spas',
#  'Restaurants',
#  'Museums',
#  'Event Planning & Services',
#  'Hotels',
#  'Cinema',
#  'Resorts',
#  'Day Spas',
#  'Medical Centers',
#  'Health & Medical',
#  'Coffee & Tea',
#  'Food',
#  'Fast Food',
#  'Sandwiches',
#  'Chicken Shop',
#  'Restaurants',
#  'Grocery',
#  'Food',
#  'Pizza',
#  'Restaurants',
#  'Shopping',
#  'Department Stores',
#  'Grocery',
#  'Fashion',
#  'Food',
#  'Electronics',
#  'Furniture Stores',
#  'Home & Garden',
#  'Fast Food',
#  'Restaurants',
#  'Food',
#  'Burgers',
#  'Coffee & Tea',
#  'Wildlife Control',
#  'Local Services',
#  'Pest Control',
#  'Apartments',
#  'Roofing',
#  'Real Estate',
#  'Home Services',
#  'Bars',
#  'Wine Bars',
#  'Nightlife',
#  'Beer Bar',
#  'Restaurants',
#  'American (New)',
#  'Burgers',
#  'Fast Food',
#  'Steakhouses',
#  'Japanese',
#  'Chinese',
#  'Restaurants',
#  'Thai',
#  'Auto Glass Services',
#  'Automotive',
#  'Windshield Installation & Repair',
#  'Restaurants',
#  'Bakeries',
#  'Caterers',
#  'Bagels',
#  'Food',
#  'Event Planning & Services',
#  'Endodontists',
#  'General Dentistry',
#  'Health & Medical',
#  'Cosmetic Dentists',
#  'Dentists',
#  'Food',
#  'Coffee & Tea',
#  'Carpeting',
#  'Shopping',
#  'Home Services',
#  'Flooring',
#  'Rugs',
#  'Home & Garden',
#  'Arts & Entertainment',
#  'Nightlife',
#  'Jazz & Blues',
#  'Restaurants',
#  'Pizza',
#  'Southern',
#  'Hotels & Travel',
#  'Event Planning & Services',
#  'Hotels',
#  'American (Traditional)',
#  'Restaurants',
#  'Burgers',
#  'Wraps',
#  'Sandwiches',
#  'Bars',
#  'Nightlife',
#  'Beer Bar',
#  'Donuts',
#  'Food',
#  'Motorcycle Rental',
#  'Tours',
#  'Hiking',
#  'Mountain Biking',
#  'ATV Rentals/Tours',
#  'RV Rental',
#  'Hotels & Travel',
#  'Arts & Entertainment',
#  'Active Life',
#  'Drugstores',
#  'Convenience Stores',
#  'Food',
#  'Shopping',
#  'Steakhouses',
#  'Restaurants',
#  'Sushi Bars',
#  'Japanese',
#  'Home Services',
#  'Tree Services',
#  'Bars',
#  'Pubs',
#  'Nightlife',
#  'Arts & Entertainment',
#  'Irish',
#  'Restaurants',
#  'Music Venues',
#  'Trailer Dealers',
#  'Auto Parts & Supplies',
#  'Auto Repair',
#  'RV Repair',
#  'Local Services',
#  'Trailer Repair',
#  'RV Dealers',
#  'Shopping',
#  'Automotive',
#  'Propane',
#  'Outdoor Gear',
#  'Sporting Goods',
#  'Automotive',
#  'Auto Detailing',
#  'Car Wash',
#  'Auto Glass Services',
#  'Car Dealers',
#  'Automotive',
#  'Used Car Dealers',
#  'Auto Repair',
#  'Beauty & Spas',
#  'Hair Removal',
#  'Day Spas',
#  'Skin Care',
#  'Sports Bars',
#  'Bars',
#  'Nightlife',
#  'Italian',
#  'Restaurants',
#  'Pizza',
#  'Restaurants',
#  'Breakfast & Brunch',
#  'Vegan',
#  'Bagels',
#  'Food',
#  'Coffee & Tea',
#  'Local Services',
#  'Shipping Centers',
#  'Notaries',
#  'Printing Services',
#  'Mailbox Centers',
#  'Specialty Food',
#  'Food',
#  'Shaved Ice',
#  'Juice Bars & Smoothies',
#  'Fruits & Veggies',
#  'Home Services',
#  'Real Estate',
#  'Apartments',
#  'Appliances',
#  'Mattresses',
#  'Shopping',
#  'Home & Garden',
#  'Restaurants',
#  'Italian',
#  'Nightlife',
#  'Bars',
#  'Cocktail Bars',
#  'Tapas/Small Plates',
#  'Machine Shops',
#  'Local Services',
#  'Automotive',
#  'Auto Parts & Supplies',
#  'Beauty & Spas',
#  'Waxing',
#  'Nail Salons',
#  'Hair Removal',
#  'Pet Services',
#  'Pet Sitting',
#  'Pets',
#  'Irish Pub',
#  'Bars',
#  'Restaurants',
#  'Irish',
#  'Nightlife',
#  'Restaurants',
#  'Breakfast & Brunch',
#  'Coffee Roasteries',
#  'Coffee & Tea',
#  'Food',
#  'Restaurants',
#  'Breakfast & Brunch',
#  'Health & Medical',
#  'Doctors',
#  'Endocrinologists',
#  'Internal Medicine',
#  'Dermatologists',
#  'Shopping',
#  'Fashion',
#  'Outdoor Gear',
#  'Active Life',
#  'Golf Lessons',
#  'Sporting Goods',
#  'Golf Equipment',
#  'Golf',
#  'Fitness & Instruction',
#  'Sports Wear',
#  'Active Life',
#  'Fitness & Instruction',
#  'Trainers',
#  'Gyms',
#  'Active Life',
#  'Shopping',
#  'Fishing',
#  'Hunting & Fishing Supplies',
#  'Sporting Goods',
#  'Diagnostic Imaging',
#  'Diagnostic Services',
#  'Health & Medical',
#  'Medical Centers',
#  'Professional Sports Teams',
#  'Arts & Entertainment',
#  'Home Services',
#  'Professional Services',
#  'Home Cleaning',
#  'Office Cleaning',
#  'Shopping',
#  'Furniture Stores',
#  'Home & Garden',
#  'Mountain Biking',
#  'Bike Repair/Maintenance',
#  'Shopping',
#  'Bikes',
#  'Active Life',
#  'Local Services',
#  'Sporting Goods',
#  'Cupcakes',
#  'Caribbean',
#  'Restaurants',
#  'Trinidadian',
#  'Food',
#  'Bakeries',
#  'Cafes',
#  'Apartments',
#  'Real Estate',
#  'Home Services',
#  'Body Shops',
#  'Automotive',
#  'Beauty & Spas',
#  'Piercing',
#  'Tattoo',
#  'Orthodontists',
#  'Health & Medical',
#  'Oral Surgeons',
#  'General Dentistry',
#  'Dentists',
#  'Cosmetic Dentists',
#  'Health & Medical',
#  'Medical Spas',
#  'Beauty & Spas',
#  'Skin Care',
#  'Makeup Artists',
#  'Real Estate',
#  'Apartments',
#  'Home Services',
#  'Barbers',
#  'Beauty & Spas',
#  'Caribbean',
#  'Food',
#  'Restaurants',
#  'Food Trucks',
#  'Italian',
#  'Restaurants',
#  'Salad',
#  'Bars',
#  'Venues & Event Spaces',
#  'Wine Bars',
#  'Nightlife',
#  'Event Planning & Services',
#  'Makeup Artists',
#  'Blow Dry/Out Services',
#  'Beauty & Spas',
#  'Hair Salons',
#  'Nail Salons',
#  'Eyebrow Services',
#  'Italian',
#  'Seafood',
#  'American (Traditional)',
#  'Steakhouses',
#  'Restaurants',
#  'Comfort Food',
#  'Event Planning & Services',
#  'Hotels & Travel',
#  'Hotels',
#  'Venues & Event Spaces',
#  'Beauty & Spas',
#  'Hair Salons',
#  'Sandwiches',
#  'Chicken Wings',
#  'Restaurants',
#  'Donuts',
#  'Food',
#  'Home Services',
#  'Windows Installation',
#  'Thai',
#  'Vietnamese',
#  'Chinese',
#  'Restaurants',
#  'Shipping Centers',
#  'Notaries',
#  'Local Services',
#  'Printing Services',
#  'Mailbox Centers',
#  'Beauty & Spas',
#  'Eyelash Service',
#  'Skin Care',
#  'Tanning',
#  'Restaurants',
#  'Sandwiches',
#  'Restaurants',
#  'Acai Bowls',
#  'Vegan',
#  'Organic Stores',
#  'Vegetarian',
#  'Food',
#  'Juice Bars & Smoothies',
#  'Pet Services',
#  'Pets',
#  'Pet Training',
#  'Restaurants',
#  'Salad',
#  'Pakistani',
#  'Indian',
#  'Cocktail Bars',
#  'Food',
#  'Food Delivery Services',
#  'Soup',
#  'Halal',
#  'Bars',
#  'Nightlife',
#  'Street Vendors',
#  'Food',
#  'Food Trucks',
#  'Greek',
#  'Food Stands',
#  'Restaurants',
#  'Mediterranean',
#  'Local Flavor',
#  'Public Art',
#  'Museums',
#  'Nightlife',
#  'Arts & Entertainment',
#  'Music Venues',
#  'Education',
#  'Preschools',
#  'Local Services',
#  'Child Care & Day Care',
#  'Elementary Schools',
#  'Massage',
#  'Beauty & Spas',
#  'Convenience Stores',
#  'Food',
#  'Grocery',
#  'Coffee & Tea',
#  'Beer',
#  'Wine & Spirits',
#  'Auto Repair',
#  'Automotive',
#  'Car Wash',
#  'Automotive',
#  'Animal Shelters',
#  'Pet Adoption',
#  'Pets',
#  'Salad',
#  'Hot Dogs',
#  'Burgers',
#  'Restaurants',
#  'American (Traditional)',
#  'Fast Food',
#  'Nightlife',
#  'Pubs',
#  'American (Traditional)',
#  'Restaurants',
#  'Bars',
#  'Flooring',
#  'Refinishing Services',
#  'Home Services',
#  'Italian',
#  'Restaurants',
#  'Steakhouses',
#  'Tires',
#  'Automotive',
#  'Auto Repair',
#  'Oil Change Stations',
#  'Auto Detailing',
#  'Car Wash',
#  'Restaurants',
#  'Mexican',
#  'American (Traditional)',
#  'Electronics',
#  'Musical Instruments & Teachers',
#  'Shopping',
#  'Churches',
#  'Religious Organizations',
#  'Historical Tours',
#  'Tours',
#  'Hotels & Travel',
#  'Food Tours',
#  'Walking Tours',
#  'Restaurants',
#  'Mexican',
#  'Pizza',
#  'Fast Food',
#  'Gluten-Free',
#  'Restaurants',
#  'Salad',
#  'Local Services',
#  'Community Service/Non-Profit',
#  'Health & Medical',
#  'Doctors',
#  'Family Practice',
#  'Medical Centers',
#  'Counseling & Mental Health',
#  'Restaurants',
#  'Burgers',
#  'Shopping',
#  'Home Decor',
#  'Flooring',
#  'Home Services',
#  'Kitchen & Bath',
#  'Home & Garden',
#  'Building Supplies',
#  'Interior Design',
#  'Fashion',
#  'Discount Store',
#  'Sporting Goods',
#  'Military Surplus',
#  'Outdoor Gear',
#  'Shopping',
#  'Hobby Shops',
#  'Uniforms',
#  'Food',
#  'Coffee & Tea',
#  'Bakeries',
#  'Restaurants',
#  'Cafes',
#  'Restaurants',
#  'American (New)',
#  'Breakfast & Brunch',
#  'Burgers',
#  'Home Services',
#  'Keys & Locksmiths',
#  'Barbeque',
#  'Restaurants',
#  'Hot Dogs',
#  'Doctors',
#  'Health & Medical',
#  'Urgent Care',
#  'Walk-in Clinics',
#  'Medical Centers',
#  'Family Practice',
#  'Event Planning & Services',
#  'Restaurants',
#  'Empanadas',
#  'Caterers',
#  'Food',
#  'Desserts',
#  'Comfort Food',
#  'American (Traditional)',
#  'Food Trucks',
#  'American (New)',
#  'Restaurants',
#  'Active Life',
#  'Parks',
#  'Dog Parks',
#  'Restaurants',
#  'Italian',
#  'Nightlife',
#  'Southern',
#  'Bars',
#  'Breakfast & Brunch',
#  'Pizza',
#  'Food',
#  'Wholesalers',
#  'Coffee Roasteries',
#  'Professional Services',
#  'Coffee & Tea',
#  'Barbers',
#  'Education',
#  'Hair Salons',
#  'Cosmetology Schools',
#  'Specialty Schools',
#  'Beauty & Spas',
#  'Health & Medical',
#  'Dermatologists',
#  'Doctors',
#  'Mexican',
#  'Beer Bar',
#  'Bars',
#  'Sports Bars',
#  'Nightlife',
#  'Restaurants',
#  'Tacos',
#  'Active Life',
#  'Escape Games',
#  'Barbers',
#  'Beauty & Spas',
#  'Shopping',
#  'Vape Shops',
#  'Head Shops',
#  'Tobacco Shops',
#  'Korean',
#  'Restaurants',
#  'Self Storage',
#  'Local Services',
#  'Auto Parts & Supplies',
#  'Automotive',
#  'Pets',
#  'Pet Groomers',
#  'Pet Training',
#  'Pet Services',
#  'Pet Stores',
#  'Japanese',
#  'Restaurants',
#  'Sushi Bars',
#  'Chinese',
#  'Bars',
#  'Nightlife',
#  'Pubs',
#  'Shopping',
#  'Hair Salons',
#  'Professional Services',
#  'Beauty & Spas',
#  'Cosmetics & Beauty Supply',
#  'Beauty & Spas',
#  'Shopping',
#  'Cosmetics & Beauty Supply',
#  'Skin Care',
#  'Masonry/Concrete',
#  'Gardeners',
#  'Tree Services',
#  'Landscape Architects',
#  'Landscaping',
#  'Irrigation',
#  ...]

# %%
len(set(all_categories))
# Out:
# 1270

# %%
def check_categories(categories):
    """Return all food related categories"""
    try:
        return 'Restaurants' in categories.split(', ')
    except Exception:
        return False

filtered_business = business_df[business_df['categories'].apply(check_categories)]
len(filtered_business)
# Out:
# 30918

# %%
# only keep open businesses
filtered_business = filtered_business[filtered_business['is_open'] == 1]
len(filtered_business)
# Out:
# 29835

# %%
review_df = pd.read_json(review_path, lines=True)
review_df.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  Z6-2rrZvRnDcXpBiqhsk9A  pk3SPF_Ip1t65E3G9xFoKA  -e8RwknT5szoLk9uBZjzcw
# 1  C08Oi6p84SfNq_fh4GPKEQ  kk4GynEiF13My49uJ3hP7w  XYjlZTXifIjpAbPW33tCXw
# 2  1skKNG9rGSArmPXfvlcy6Q  DDpOQU-_tXEdHsoJN-REOg  bSJczuohHVko33UT82hnfA
# 3  oabif-hAnvLWOmSc4HCATQ  s4Cd9whJ8_g_p4iABq4hyQ  7UbXvL4SnVEDtx8oJbbuhw
# 4  mGW-EduqWdKsdHYVj8vSag  WXVo7Ff1NQPE71dnb0pK-A  UuRZpgZsHX7PyykHV3wbZg
#
#    stars  useful  funny  cool  \
# 0      5       1      0     0
# 1      5       0      0     0
# 2      2       0      0     0
# 3      2       0      1     0
# 4      5       0      0     0
#
#                                                 text                date
# 0  Had a great time tasting for my moms birthday.... 2021-03-01 00:00:43
# 1  Best place for ice cream on the go. Very covid... 2021-03-01 00:00:52
# 2  I went to blaze yesterday around this same tim... 2021-03-01 00:01:08
# 3  The gas is cheap, that's about it.  The servic... 2021-03-01 00:01:25
# 4  It was pretty late by the time I went in so th... 2021-03-01 00:01:41

# %%
filtered_reviews = pd.merge(review_df, users_df, on='user_id', how='inner')
filtered_reviews = pd.merge(filtered_reviews, business_df, on='business_id', how='inner')

# %%
print(len(filtered_reviews))
filtered_reviews.head()
# Out:
# 366252
#                 review_id                 user_id             business_id  \
# 0  1skKNG9rGSArmPXfvlcy6Q  DDpOQU-_tXEdHsoJN-REOg  bSJczuohHVko33UT82hnfA
# 1  mGW-EduqWdKsdHYVj8vSag  WXVo7Ff1NQPE71dnb0pK-A  UuRZpgZsHX7PyykHV3wbZg
# 2  fpFl0aaBvH-ODbFlG8Nqew  kk4GynEiF13My49uJ3hP7w  3Z4rhPFO6XWJRQipEIZCWA
# 3  d0BNtceSzXS34hMhXKzhJw  9lxeey8azLxu_DhcsrCO2Q  aRb_ToTRcHa9BICLLj8n-A
# 4  GEsSANWisPzNnR7MwSRLOA  x2PV9PpcRbJm74a9mb07ug  q7rBuON2WEIhdfz-AIYFFg
#
#    stars  useful  funny  cool  \
# 0      2       0      0     0
# 1      5       0      0     0
# 2      3       0      0     0
# 3      4       0      0     0
# 4      5       1      0     1
#
#                                                 text                date  \
# 0  I went to blaze yesterday around this same tim... 2021-03-01 00:01:08
# 1  It was pretty late by the time I went in so th... 2021-03-01 00:01:41
# 2  Always been a place with great atmosphere and ... 2021-03-01 00:02:54
# 3  This is becoming our go to takeout restaurant.... 2021-03-01 00:03:06
# 4  Tryed a new restaurant tonight! Mediterranean ... 2021-03-01 00:03:53
#
#   user_name  ...  cat_seafood  cat_salad  cat_chicken_wings  \
# 0     Malik  ...            0          1                  0
# 1     Sarah  ...            0          0                  0
# 2       Joe  ...            0          0                  0
# 3     David  ...            0          0                  0
# 4     Nancy  ...            0          0                  0
#
#    cat_event_planning_&_services  cat_chinese  cat_cafes  weekly_hours  \
# 0                              0            0          0          89.0
# 1                              0            0          1          56.0
# 2                              0            0          0          64.0
# 3                              0            0          0          53.0
# 4                              0            0          0          55.0
#
#    open_weekends  open_late  days_open
# 0            1.0        1.0        7.0
# 1            1.0        0.0        7.0
# 2            1.0        1.0        6.0
# 3            1.0        0.0        6.0
# 4            1.0        0.0        6.0
#
# [5 rows x 73 columns]

# %%
filtered_reviews.columns
# Out:
# Index(['review_id', 'user_id', 'business_id', 'stars', 'useful', 'funny',
#        'cool', 'text', 'date', 'user_name', 'user_review_count',
#        'yelping_years', 'reviews_per_year', 'engagement_score',
#        'engagement_per_review', 'total_compliments', 'compliments_per_review',
#        'compliment_type_count', 'num_friends', 'friend_density',
#        'friend_to_fan_ratio', 'elite_years_count', 'is_elite', 'elite_score',
#        'tough_reviewer', 'social_compliments', 'thoughtful_compliments',
#        'business_name', 'rating', 'business_review_count', 'is_open',
#        'popularity', 'high_rating', 'attr_businessacceptscreditcards',
#        'attr_restaurantstakeout', 'attr_restaurantsdelivery',
#        'attr_outdoorseating', 'attr_byappointmentonly', 'attr_caters',
#        'attr_restaurantsgoodforgroups', 'attr_restaurantsreservations',
#        'attr_restaurantspricerange2', 'attr_bikeparking',
#        'attr_wheelchairaccessible', 'attr_goodforkids', 'attr_dogsallowed',
#        'attr_hastv', 'attr_happyhour', 'attr_drivethru', 'cat_restaurants',
#        'cat_food', 'cat_nightlife', 'cat_sandwiches', 'cat_bars',
#        'cat_american_(traditional)', 'cat_fast_food', 'cat_pizza',
#        'cat_breakfast_&_brunch', 'cat_burgers', 'cat_american_(new)',
#        'cat_mexican', 'cat_italian', 'cat_coffee_&_tea', 'cat_seafood',
#        'cat_salad', 'cat_chicken_wings', 'cat_event_planning_&_services',
#        'cat_chinese', 'cat_cafes', 'weekly_hours', 'open_weekends',
#        'open_late', 'days_open'],
#       dtype='object')

# %%
filtered_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366252 entries, 0 to 366251
# Data columns (total 43 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   review_id              366252 non-null  object
#  1   user_id                366252 non-null  object
#  2   business_id            366252 non-null  object
#  3   stars                  366252 non-null  int64
#  4   useful_x               366252 non-null  int64
#  5   funny_x                366252 non-null  int64
#  6   cool_x                 366252 non-null  int64
#  7   text                   366252 non-null  object
#  8   date                   366252 non-null  datetime64[ns]
#  9   user_name              366252 non-null  object
#  10  user_review_count      366252 non-null  int64
#  11  yelping_since          366252 non-null  object
#  12  useful_y               366252 non-null  int64
#  13  funny_y                366252 non-null  int64
#  14  cool_y                 366252 non-null  int64
#  15  elite                  366252 non-null  object
#  16  friends                366252 non-null  object
#  17  fans                   366252 non-null  int64
#  18  average_stars          366252 non-null  float64
#  19  compliment_hot         366252 non-null  int64
#  20  compliment_more        366252 non-null  int64
#  21  compliment_profile     366252 non-null  int64
#  22  compliment_cute        366252 non-null  int64
#  23  compliment_list        366252 non-null  int64
#  24  compliment_note        366252 non-null  int64
#  25  compliment_plain       366252 non-null  int64
#  26  compliment_cool        366252 non-null  int64
#  27  compliment_funny       366252 non-null  int64
#  28  compliment_writer      366252 non-null  int64
#  29  compliment_photos      366252 non-null  int64
#  30  business_name          366252 non-null  object
#  31  address                366252 non-null  object
#  32  city                   366252 non-null  object
#  33  state                  366252 non-null  object
#  34  postal_code            366252 non-null  object
#  35  latitude               366252 non-null  float64
#  36  longitude              366252 non-null  float64
#  37  rating                 366252 non-null  float64
#  38  business_review_count  366252 non-null  int64
#  39  is_open                366252 non-null  int64
#  40  attributes             364065 non-null  object
#  41  categories             366252 non-null  object
#  42  hours                  357572 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(22), object(16)
# memory usage: 120.2+ MB

# %%
photos_df = pd.read_json(photos_path, lines=True)
photos_df.head()
# Out:
#                  photo_id             business_id  \
# 0  zsvj7vloL4L5jhYyPIuVwg  Nk-SJhPlDBkAZvfsADtccA
# 1  HCUdRJHHm_e0OCTlZetGLg  yVZtL5MmrpiivyCIrVkGgA
# 2  vkr8T0scuJmGVvN2HJelEA  _ab50qdWOk0DdB6XOrBitw
# 3  pve7D6NUrafHW3EAORubyw  SZU9c8V2GuREDN5KgyHFJw
# 4  H52Er-uBg6rNrHcReWTD2w  Gzur0f0XMkrVxIwYJvOt2g
#
#                                              caption    label
# 0  Nice rock artwork everywhere and craploads of ...   inside
# 1                                                     outside
# 2                                     oyster shooter    drink
# 3                                      Shrimp scampi     food
# 4                                                        food

# %%
from sklearn.preprocessing import LabelEncoder

# Encode user and business ids using LabelEncoder   
le_user = LabelEncoder()
le_business = LabelEncoder()
filtered_reviews['user_id_enc'] = le_user.fit_transform(filtered_reviews['user_id'])
filtered_reviews['business_id_enc'] = le_business.fit_transform(filtered_reviews['business_id'])

# %%
filtered_reviews.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  1skKNG9rGSArmPXfvlcy6Q  DDpOQU-_tXEdHsoJN-REOg  bSJczuohHVko33UT82hnfA
# 1  mGW-EduqWdKsdHYVj8vSag  WXVo7Ff1NQPE71dnb0pK-A  UuRZpgZsHX7PyykHV3wbZg
# 2  fpFl0aaBvH-ODbFlG8Nqew  kk4GynEiF13My49uJ3hP7w  3Z4rhPFO6XWJRQipEIZCWA
# 3  d0BNtceSzXS34hMhXKzhJw  9lxeey8azLxu_DhcsrCO2Q  aRb_ToTRcHa9BICLLj8n-A
# 4  GEsSANWisPzNnR7MwSRLOA  x2PV9PpcRbJm74a9mb07ug  q7rBuON2WEIhdfz-AIYFFg
#
#    stars  useful_x  funny_x  cool_x  \
# 0      2         0        0       0
# 1      5         0        0       0
# 2      3         0        0       0
# 3      4         0        0       0
# 4      5         1        0       1
#
#                                                 text                date  \
# 0  I went to blaze yesterday around this same tim... 2021-03-01 00:01:08
# 1  It was pretty late by the time I went in so th... 2021-03-01 00:01:41
# 2  Always been a place with great atmosphere and ... 2021-03-01 00:02:54
# 3  This is becoming our go to takeout restaurant.... 2021-03-01 00:03:06
# 4  Tryed a new restaurant tonight! Mediterranean ... 2021-03-01 00:03:53
#
#   user_name  ...   latitude   longitude  rating  business_review_count  \
# 0     Malik  ...  29.948395  -90.075281     4.0                    302
# 1     Sarah  ...  34.425720 -119.705241     4.0                    761
# 2       Joe  ...  28.011587  -82.788281     3.5                    806
# 3     David  ...  40.152561  -75.137371     4.5                    174
# 4     Nancy  ...  38.789061  -90.549623     5.0                    123
#
#    is_open                                         attributes  \
# 0        1  {'Ambience': '{'romantic': False, 'intimate': ...
# 1        1  {'BusinessParking': '{'garage': False, 'street...
# 2        1  {'RestaurantsReservations': 'True', 'GoodForKi...
# 3        1  {'RestaurantsPriceRange2': '2', 'RestaurantsTa...
# 4        1  {'BikeParking': 'True', 'BYOB': 'False', 'Rest...
#
#                                           categories  \
# 0  Pizza, Fast Food, Gluten-Free, Restaurants, Salad
# 1  Bakeries, Cafes, Coffee & Tea, Food, Desserts,...
# 2  Mexican, Restaurants, Desserts, Vegetarian, Fo...
# 3                            Restaurants, Vietnamese
# 4         Mediterranean, Restaurants, Middle Eastern
#
#                                                hours  user_id_enc  \
# 0  {'Monday': '0:0-0:0', 'Tuesday': '11:0-22:0', ...        43324
# 1  {'Monday': '8:0-16:0', 'Tuesday': '8:0-16:0', ...       101817
# 2  {'Tuesday': '11:0-21:30', 'Wednesday': '11:0-2...       148081
# 3  {'Monday': '11:0-19:0', 'Wednesday': '11:0-20:...        32871
# 4  {'Tuesday': '10:0-20:0', 'Wednesday': '15:0-20...       185620
#
#    business_id_enc
# 0            18402
# 1            14941
# 2             2234
# 3            17949
# 4            25283
#
# [5 rows x 45 columns]

# %%
users_df.columns
# Out:
# Index(['user_id', 'user_name', 'user_review_count', 'yelping_years',
#        'reviews_per_year', 'engagement_score', 'engagement_per_review',
#        'total_compliments', 'compliments_per_review', 'compliment_type_count',
#        'num_friends', 'friend_density', 'friend_to_fan_ratio',
#        'elite_years_count', 'is_elite', 'elite_score', 'tough_reviewer',
#        'social_compliments', 'thoughtful_compliments'],
#       dtype='object')

# %%
business_df.columns
# Out:
# Index(['business_id', 'business_name', 'rating', 'business_review_count',
#        'is_open', 'popularity', 'high_rating',
#        'attr_businessacceptscreditcards', 'attr_restaurantstakeout',
#        'attr_restaurantsdelivery', 'attr_outdoorseating',
#        'attr_byappointmentonly', 'attr_caters',
#        'attr_restaurantsgoodforgroups', 'attr_restaurantsreservations',
#        'attr_restaurantspricerange2', 'attr_bikeparking',
#        'attr_wheelchairaccessible', 'attr_goodforkids', 'attr_dogsallowed',
#        'attr_hastv', 'attr_happyhour', 'attr_drivethru', 'cat_restaurants',
#        'cat_food', 'cat_nightlife', 'cat_sandwiches', 'cat_bars',
#        'cat_american_(traditional)', 'cat_fast_food', 'cat_pizza',
#        'cat_breakfast_&_brunch', 'cat_burgers', 'cat_american_(new)',
#        'cat_mexican', 'cat_italian', 'cat_coffee_&_tea', 'cat_seafood',
#        'cat_salad', 'cat_chicken_wings', 'cat_event_planning_&_services',
#        'cat_chinese', 'cat_cafes', 'weekly_hours', 'open_weekends',
#        'open_late', 'days_open'],
#       dtype='object')
