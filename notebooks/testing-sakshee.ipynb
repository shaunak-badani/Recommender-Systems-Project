# %%
import os
import pandas as pd

# %%
base_path = '../data'
business_path = os.path.join(base_path, 'yelp_academic_dataset_business.json')
review_path = os.path.join(base_path, 'yelp_academic_dataset_review.json')
user_path = os.path.join(base_path, 'yelp_academic_dataset_user.json')
photos_path = os.path.join(base_path, 'filtered_photos.json')

# %%
users_df = pd.read_json(user_path, lines=True)
# rename review_count to user_review_count
users_df.rename(columns={'review_count': 'user_review_count', 'name': 'user_name'}, inplace=True)
users_df.head()
# Out:
#                   user_id user_name  user_review_count        yelping_since  \
# 0  qVc8ODYU5SZjKXVBgXdI7w    Walker                585  2007-01-25 16:47:26
# 1  j14WgRoU_-2ZE1aw1dXrJg    Daniel               4333  2009-01-25 04:35:42
# 2  hA5lMy-EnncsH4JoR-hFGQ     Karen                 79  2007-01-05 19:40:59
# 3  E9kcWJdJUHuTKfQurPljwA      Mike                358  2008-12-11 22:11:56
# 4  4ZaqBJqt7laPPs8xfWvr6A      Nina                801  2008-08-16 22:43:21
#
#    useful  funny   cool                                              elite  \
# 0    7217   1259   5994                                               2007
# 1   43091  13066  27281  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 2      29     15      7
# 3     399    102    143
# 4    1944    616    737  2010,2011,2012,2013,2014,2015,2016,2017,2018,2...
#
#                                              friends  fans  ...  \
# 0  NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267  ...
# 1  ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...  3138  ...
# 2  PBK4q9KEEBHhFvSXCUirIw, 3FWPpM7KU1gXeOM_ZbYMbA...     1  ...
# 3  y2GyxJF5VQWohxgw_GR7Jw, 0NRn4eY3JWN0IFqvOSa5gA...    23  ...
# 4  v56_o8iCNYGB2JFVIhOwQA, yFLNHDlCriteboCVKjtpbA...    75  ...
#
#    compliment_more  compliment_profile  compliment_cute  compliment_list  \
# 0               65                  55               56               18
# 1              264                 184              157              251
# 2                1                   0                0                0
# 3                7                   2                0                0
# 4                5                   1               10                0
#
#    compliment_note  compliment_plain  compliment_cool  compliment_funny  \
# 0              232               844              467               467
# 1             1847              7054             3131              3131
# 2                1                 1                0                 0
# 3                8                 6               12                12
# 4               54                71               46                46
#
#    compliment_writer  compliment_photos
# 0                239                180
# 1               1521               1946
# 2                  0                  0
# 3                  5                  0
# 4                 39                 10
#
# [5 rows x 22 columns]

# %%
business_df = pd.read_json(business_path, lines=True)
# rename stars to rating
business_df.rename(columns={'stars': 'rating', 'review_count': 'business_review_count', 'name': 'business_name'}, inplace=True)
business_df.head()
# Out:
#               business_id             business_name  \
# 0  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 1  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 2  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# 3  CF33F8-E6oudUQ46HnavjQ            Sonic Drive-In
# 4  qkRM_2X51Yqxk3btlwAQIg            Temple Beth-El
#
#                            address            city state postal_code  \
# 0  87 Grasso Plaza Shopping Center          Affton    MO       63123
# 1                      935 Race St    Philadelphia    PA       19107
# 2                    101 Walnut St      Green Lane    PA       18054
# 3                    615 S Main St    Ashland City    TN       37015
# 4               400 Pasadena Ave S  St. Petersburg    FL       33707
#
#     latitude  longitude  rating  business_review_count  is_open  \
# 0  38.551126 -90.335695     3.0                     15        1
# 1  39.955505 -75.155564     4.0                     80        1
# 2  40.338183 -75.471659     4.5                     13        1
# 3  36.269593 -87.058943     2.0                      6        1
# 4  27.766590 -82.732983     3.5                      5        1
#
#                                           attributes  \
# 0             {'BusinessAcceptsCreditCards': 'True'}
# 1  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 2  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
# 3  {'BusinessParking': 'None', 'BusinessAcceptsCr...
# 4                                               None
#
#                                           categories  \
# 0  Shipping Centers, Local Services, Notaries, Ma...
# 1  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 2                          Brewpubs, Breweries, Food
# 3  Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 4                Synagogues, Religious Organizations
#
#                                                hours
# 0  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 1  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 2  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...
# 3  {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...
# 4  {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...

# %%
len(business_df)
# Out:
# 84551

# %%
all_categories = []
for i, row in business_df.iterrows():
    if row['categories'] is not None:
        current_categories = row['categories'].split(', ')
        for category in current_categories:
            all_categories.append(category)

all_categories
# Out:
# ['Shipping Centers',
#  'Local Services',
#  'Notaries',
#  'Mailbox Centers',
#  'Printing Services',
#  'Restaurants',
#  'Food',
#  'Bubble Tea',
#  'Coffee & Tea',
#  'Bakeries',
#  'Brewpubs',
#  'Breweries',
#  'Food',
#  'Burgers',
#  'Fast Food',
#  'Sandwiches',
#  'Food',
#  'Ice Cream & Frozen Yogurt',
#  'Restaurants',
#  'Synagogues',
#  'Religious Organizations',
#  'Ice Cream & Frozen Yogurt',
#  'Fast Food',
#  'Burgers',
#  'Restaurants',
#  'Food',
#  'Department Stores',
#  'Shopping',
#  'Fashion',
#  'Vietnamese',
#  'Food',
#  'Restaurants',
#  'Food Trucks',
#  'American (Traditional)',
#  'Restaurants',
#  'Diners',
#  'Breakfast & Brunch',
#  'Sushi Bars',
#  'Restaurants',
#  'Japanese',
#  'Automotive',
#  'Auto Parts & Supplies',
#  'Auto Customization',
#  'Automotive',
#  'Car Rental',
#  'Hotels & Travel',
#  'Truck Rental',
#  'Korean',
#  'Restaurants',
#  'Shopping',
#  'Books',
#  'Mags',
#  'Music & Video',
#  'Bookstores',
#  'Steakhouses',
#  'Asian Fusion',
#  'Restaurants',
#  'Restaurants',
#  'Italian',
#  'Pizza',
#  'Chicken Wings',
#  'Sandwiches',
#  'Restaurants',
#  'Trampoline Parks',
#  'Active Life',
#  'Pizza',
#  'Restaurants',
#  'Event Planning & Services',
#  'Hotels',
#  'Hotels & Travel',
#  'Eatertainment',
#  'Arts & Entertainment',
#  'Brewpubs',
#  'American (Traditional)',
#  'Bakeries',
#  'Breweries',
#  'Food',
#  'Restaurants',
#  'Hair Salons',
#  'Hair Extensions',
#  'Beauty & Spas',
#  'Wigs',
#  'Shopping',
#  'Restaurants',
#  'Specialty Food',
#  'Steakhouses',
#  'Food',
#  'Italian',
#  'Pizza',
#  'Pasta Shops',
#  'Health & Medical',
#  'Beauty & Spas',
#  'Laser Hair Removal',
#  'Doctors',
#  'Hair Removal',
#  'Chiropractors',
#  'Weight Loss Centers',
#  'Sports Medicine',
#  'Medical Spas',
#  'Skin Care',
#  'Restaurants',
#  'Italian',
#  'Food',
#  'Grocery',
#  'Convenience Stores',
#  'Hotels',
#  'Hotels & Travel',
#  'Event Planning & Services',
#  'Vitamins & Supplements',
#  'Ice Cream & Frozen Yogurt',
#  'Food',
#  'Juice Bars & Smoothies',
#  'Shopping',
#  'Sports Bars',
#  'American (New)',
#  'American (Traditional)',
#  'Nightlife',
#  'Bars',
#  'Restaurants',
#  'Uniforms',
#  'Shopping',
#  'Hotels & Travel',
#  'Tours',
#  'Local Flavor',
#  'Local Services',
#  'Appliances & Repair',
#  'Chocolatiers & Shops',
#  'Specialty Food',
#  'Candy Stores',
#  'Food',
#  'Food Trucks',
#  'Food',
#  'Shopping',
#  'Baby Gear & Furniture',
#  'Home Decor',
#  'Furniture Stores',
#  'Home & Garden',
#  'Banks & Credit Unions',
#  'Financial Services',
#  'American (Traditional)',
#  'Bars',
#  'Nightlife',
#  'Sports Bars',
#  'Restaurants',
#  'Health & Medical',
#  'Personal Care Services',
#  'Beauty & Spas',
#  'Massage',
#  'Nail Salons',
#  'American (Traditional)',
#  'Sports Bars',
#  'Restaurants',
#  'Bars',
#  'Nightlife',
#  'Steakhouses',
#  'Salad',
#  'Beer Bar',
#  'Burgers',
#  'Sports Bars',
#  'Bars',
#  'Lounges',
#  'Restaurants',
#  'Salad',
#  'Wraps',
#  'Nightlife',
#  'American (New)',
#  'Food',
#  'Beer',
#  'Wine & Spirits',
#  'Breweries',
#  'Restaurants',
#  'Automotive',
#  'Delis',
#  'Gas Stations',
#  'Food',
#  'Coffee & Tea',
#  'Sandwiches',
#  'Convenience Stores',
#  'Keys & Locksmiths',
#  'Home Services',
#  'Local Services',
#  'Food',
#  'Restaurants',
#  'Salad',
#  'Coffee & Tea',
#  'Breakfast & Brunch',
#  'Sandwiches',
#  'Bakeries',
#  'Pet Groomers',
#  'Pet Sitting',
#  'Pets',
#  'Pet Services',
#  'Nightlife',
#  'Pubs',
#  'Event Planning & Services',
#  'Wine Bars',
#  'Bars',
#  'Gastropubs',
#  'Restaurants',
#  'Venues & Event Spaces',
#  'Ice Cream & Frozen Yogurt',
#  'Coffee & Tea',
#  'Restaurants',
#  'Sandwiches',
#  'Food',
#  'Home Decor',
#  'Shopping',
#  'Antiques',
#  'Books',
#  'Mags',
#  'Music & Video',
#  'Home & Garden',
#  'Towing',
#  'Automotive',
#  'Body Shops',
#  'Real Estate',
#  'Home Services',
#  'Financial Services',
#  'Mortgage Brokers',
#  'Mortgage Lenders',
#  "Women's Clothing",
#  "Men's Clothing",
#  'Accessories',
#  'Fashion',
#  'Jewelry',
#  'Department Stores',
#  'Shopping',
#  'Shoe Stores',
#  'Seafood',
#  'Restaurants',
#  'Restaurants',
#  'Seafood',
#  'Cajun/Creole',
#  'Mexican',
#  'Restaurants',
#  'Printing Services',
#  'Local Services',
#  'Shipping Centers',
#  'Couriers & Delivery Services',
#  'Notaries',
#  'Restaurants',
#  'French',
#  'Moroccan',
#  'Seafood',
#  'Mediterranean',
#  'Flooring',
#  'Handyman',
#  'Contractors',
#  'Home Services',
#  'Bars',
#  'Lounges',
#  'American (New)',
#  'Restaurants',
#  'Nightlife',
#  'Wine Bars',
#  'Eyewear & Opticians',
#  'Health & Medical',
#  'Shopping',
#  'Doctors',
#  'Optometrists',
#  'Ophthalmologists',
#  'Bars',
#  'Beer Gardens',
#  'Food',
#  'Breweries',
#  'Nightlife',
#  'Tours',
#  'Pubs',
#  'Wine Tours',
#  'Beer Tours',
#  'Hotels & Travel',
#  'Grocery',
#  'Food',
#  'Shopping',
#  'Fashion',
#  'Drugstores',
#  'Department Stores',
#  'Discount Store',
#  'Electronics',
#  'Eyewear & Opticians',
#  'Shopping',
#  'Grocery',
#  'Food',
#  'Couriers & Delivery Services',
#  'Local Services',
#  'Food',
#  'Food Delivery Services',
#  'Parenting Classes',
#  'Maternity Wear',
#  'Fashion',
#  'Education',
#  'Specialty Schools',
#  'Local Services',
#  'Home Services',
#  'Laundry Services',
#  'Child Care & Day Care',
#  'Shopping',
#  'Baby Gear & Furniture',
#  'Sandwiches',
#  'Fast Food',
#  'Restaurants',
#  'Barbers',
#  'Beauty & Spas',
#  'Hardware Stores',
#  'Home Services',
#  'Hot Tub & Pool',
#  'Pool & Hot Tub Service',
#  'Home & Garden',
#  'Shopping',
#  'Nightlife',
#  'Chicken Wings',
#  'Pubs',
#  'Bars',
#  'American (Traditional)',
#  'Restaurants',
#  'Restaurants',
#  'Chinese',
#  'Bars',
#  'Restaurants',
#  'Sports Bars',
#  'Nightlife',
#  'Custom Cakes',
#  'Food',
#  'Desserts',
#  'Cupcakes',
#  'Ice Cream & Frozen Yogurt',
#  'Discount Store',
#  'Department Stores',
#  'Food',
#  'Drugstores',
#  'Shopping',
#  'Grocery',
#  'Fashion',
#  'Mobile Phones',
#  'Auto Repair',
#  'Automotive',
#  'Tires',
#  'Oil Change Stations',
#  'Pain Management',
#  'Doctors',
#  'Health & Medical',
#  'Osteopathic Physicians',
#  'Food',
#  'Organic Stores',
#  'Specialty Food',
#  'Health Markets',
#  'Grocery',
#  'Desserts',
#  'Do-It-Yourself Food',
#  'Food',
#  'Patisserie/Cake Shop',
#  'Live/Raw Food',
#  'Restaurants',
#  'Seafood',
#  'Beer Bar',
#  'Beer',
#  'Wine & Spirits',
#  'Bars',
#  'Food',
#  'Nightlife',
#  'Buses',
#  'Transportation',
#  'Bus Tours',
#  'Hotels & Travel',
#  'Travel Agents',
#  'Travel Services',
#  'Airport Shuttles',
#  'Tours',
#  'Public Transportation',
#  'Food',
#  'Desserts',
#  'Fashion',
#  'Shopping',
#  "Men's Clothing",
#  'Shopping',
#  'Books',
#  'Mags',
#  'Music & Video',
#  'Toy Stores',
#  'Hobby Shops',
#  'Comic Books',
#  'Painters',
#  'Home Services',
#  'Decks & Railing',
#  'Contractors',
#  'Pressure Washers',
#  'Hotels',
#  'Hotels & Travel',
#  'Bed & Breakfast',
#  'Event Planning & Services',
#  'Massage',
#  'Health & Medical',
#  'Medical Spas',
#  'Beauty & Spas',
#  'Banks & Credit Unions',
#  'Financial Services',
#  'Nightlife',
#  'Restaurants',
#  'Bars',
#  'Mexican',
#  'Body Shops',
#  'Automotive',
#  'Burgers',
#  'Restaurants',
#  'Fast Food',
#  'Event Planning & Services',
#  'Caterers',
#  'Italian',
#  'Restaurants',
#  'Pharmacy',
#  'Health & Medical',
#  'Convenience Stores',
#  'Drugstores',
#  'Food',
#  'Shopping',
#  'Beauty & Spas',
#  'Tattoo',
#  'Oil Change Stations',
#  'Automotive',
#  'Tires',
#  'Auto Repair',
#  'Waxing',
#  'Hair Removal',
#  'Skin Care',
#  'Eyelash Service',
#  'Beauty & Spas',
#  'Active Life',
#  'Playgrounds',
#  'Parks',
#  'Swimming Pools',
#  'Health & Medical',
#  'Chiropractors',
#  'Beauty & Spas',
#  'Hair Stylists',
#  'Hair Extensions',
#  'Hair Salons',
#  'Dog Parks',
#  'Active Life',
#  'Parks',
#  'Venues & Event Spaces',
#  'Performing Arts',
#  'Arts & Entertainment',
#  'Hotels & Travel',
#  'Food',
#  'Convenience Stores',
#  'American (New)',
#  'Beauty & Spas',
#  'Restaurants',
#  'Museums',
#  'Event Planning & Services',
#  'Hotels',
#  'Cinema',
#  'Resorts',
#  'Day Spas',
#  'Medical Centers',
#  'Health & Medical',
#  'Coffee & Tea',
#  'Food',
#  'Fast Food',
#  'Sandwiches',
#  'Chicken Shop',
#  'Restaurants',
#  'Grocery',
#  'Food',
#  'Pizza',
#  'Restaurants',
#  'Shopping',
#  'Department Stores',
#  'Grocery',
#  'Fashion',
#  'Food',
#  'Electronics',
#  'Furniture Stores',
#  'Home & Garden',
#  'Fast Food',
#  'Restaurants',
#  'Food',
#  'Burgers',
#  'Coffee & Tea',
#  'Wildlife Control',
#  'Local Services',
#  'Pest Control',
#  'Apartments',
#  'Roofing',
#  'Real Estate',
#  'Home Services',
#  'Bars',
#  'Wine Bars',
#  'Nightlife',
#  'Beer Bar',
#  'Restaurants',
#  'American (New)',
#  'Burgers',
#  'Fast Food',
#  'Steakhouses',
#  'Japanese',
#  'Chinese',
#  'Restaurants',
#  'Thai',
#  'Auto Glass Services',
#  'Automotive',
#  'Windshield Installation & Repair',
#  'Restaurants',
#  'Bakeries',
#  'Caterers',
#  'Bagels',
#  'Food',
#  'Event Planning & Services',
#  'Endodontists',
#  'General Dentistry',
#  'Health & Medical',
#  'Cosmetic Dentists',
#  'Dentists',
#  'Food',
#  'Coffee & Tea',
#  'Carpeting',
#  'Shopping',
#  'Home Services',
#  'Flooring',
#  'Rugs',
#  'Home & Garden',
#  'Arts & Entertainment',
#  'Nightlife',
#  'Jazz & Blues',
#  'Restaurants',
#  'Pizza',
#  'Southern',
#  'Hotels & Travel',
#  'Event Planning & Services',
#  'Hotels',
#  'American (Traditional)',
#  'Restaurants',
#  'Burgers',
#  'Wraps',
#  'Sandwiches',
#  'Bars',
#  'Nightlife',
#  'Beer Bar',
#  'Donuts',
#  'Food',
#  'Motorcycle Rental',
#  'Tours',
#  'Hiking',
#  'Mountain Biking',
#  'ATV Rentals/Tours',
#  'RV Rental',
#  'Hotels & Travel',
#  'Arts & Entertainment',
#  'Active Life',
#  'Drugstores',
#  'Convenience Stores',
#  'Food',
#  'Shopping',
#  'Steakhouses',
#  'Restaurants',
#  'Sushi Bars',
#  'Japanese',
#  'Home Services',
#  'Tree Services',
#  'Bars',
#  'Pubs',
#  'Nightlife',
#  'Arts & Entertainment',
#  'Irish',
#  'Restaurants',
#  'Music Venues',
#  'Trailer Dealers',
#  'Auto Parts & Supplies',
#  'Auto Repair',
#  'RV Repair',
#  'Local Services',
#  'Trailer Repair',
#  'RV Dealers',
#  'Shopping',
#  'Automotive',
#  'Propane',
#  'Outdoor Gear',
#  'Sporting Goods',
#  'Automotive',
#  'Auto Detailing',
#  'Car Wash',
#  'Auto Glass Services',
#  'Car Dealers',
#  'Automotive',
#  'Used Car Dealers',
#  'Auto Repair',
#  'Beauty & Spas',
#  'Hair Removal',
#  'Day Spas',
#  'Skin Care',
#  'Sports Bars',
#  'Bars',
#  'Nightlife',
#  'Italian',
#  'Restaurants',
#  'Pizza',
#  'Restaurants',
#  'Breakfast & Brunch',
#  'Vegan',
#  'Bagels',
#  'Food',
#  'Coffee & Tea',
#  'Local Services',
#  'Shipping Centers',
#  'Notaries',
#  'Printing Services',
#  'Mailbox Centers',
#  'Specialty Food',
#  'Food',
#  'Shaved Ice',
#  'Juice Bars & Smoothies',
#  'Fruits & Veggies',
#  'Home Services',
#  'Real Estate',
#  'Apartments',
#  'Appliances',
#  'Mattresses',
#  'Shopping',
#  'Home & Garden',
#  'Restaurants',
#  'Italian',
#  'Nightlife',
#  'Bars',
#  'Cocktail Bars',
#  'Tapas/Small Plates',
#  'Machine Shops',
#  'Local Services',
#  'Automotive',
#  'Auto Parts & Supplies',
#  'Beauty & Spas',
#  'Waxing',
#  'Nail Salons',
#  'Hair Removal',
#  'Pet Services',
#  'Pet Sitting',
#  'Pets',
#  'Irish Pub',
#  'Bars',
#  'Restaurants',
#  'Irish',
#  'Nightlife',
#  'Restaurants',
#  'Breakfast & Brunch',
#  'Coffee Roasteries',
#  'Coffee & Tea',
#  'Food',
#  'Restaurants',
#  'Breakfast & Brunch',
#  'Health & Medical',
#  'Doctors',
#  'Endocrinologists',
#  'Internal Medicine',
#  'Dermatologists',
#  'Shopping',
#  'Fashion',
#  'Outdoor Gear',
#  'Active Life',
#  'Golf Lessons',
#  'Sporting Goods',
#  'Golf Equipment',
#  'Golf',
#  'Fitness & Instruction',
#  'Sports Wear',
#  'Active Life',
#  'Fitness & Instruction',
#  'Trainers',
#  'Gyms',
#  'Active Life',
#  'Shopping',
#  'Fishing',
#  'Hunting & Fishing Supplies',
#  'Sporting Goods',
#  'Diagnostic Imaging',
#  'Diagnostic Services',
#  'Health & Medical',
#  'Medical Centers',
#  'Professional Sports Teams',
#  'Arts & Entertainment',
#  'Home Services',
#  'Professional Services',
#  'Home Cleaning',
#  'Office Cleaning',
#  'Shopping',
#  'Furniture Stores',
#  'Home & Garden',
#  'Mountain Biking',
#  'Bike Repair/Maintenance',
#  'Shopping',
#  'Bikes',
#  'Active Life',
#  'Local Services',
#  'Sporting Goods',
#  'Cupcakes',
#  'Caribbean',
#  'Restaurants',
#  'Trinidadian',
#  'Food',
#  'Bakeries',
#  'Cafes',
#  'Apartments',
#  'Real Estate',
#  'Home Services',
#  'Body Shops',
#  'Automotive',
#  'Beauty & Spas',
#  'Piercing',
#  'Tattoo',
#  'Orthodontists',
#  'Health & Medical',
#  'Oral Surgeons',
#  'General Dentistry',
#  'Dentists',
#  'Cosmetic Dentists',
#  'Health & Medical',
#  'Medical Spas',
#  'Beauty & Spas',
#  'Skin Care',
#  'Makeup Artists',
#  'Real Estate',
#  'Apartments',
#  'Home Services',
#  'Barbers',
#  'Beauty & Spas',
#  'Caribbean',
#  'Food',
#  'Restaurants',
#  'Food Trucks',
#  'Italian',
#  'Restaurants',
#  'Salad',
#  'Bars',
#  'Venues & Event Spaces',
#  'Wine Bars',
#  'Nightlife',
#  'Event Planning & Services',
#  'Makeup Artists',
#  'Blow Dry/Out Services',
#  'Beauty & Spas',
#  'Hair Salons',
#  'Nail Salons',
#  'Eyebrow Services',
#  'Italian',
#  'Seafood',
#  'American (Traditional)',
#  'Steakhouses',
#  'Restaurants',
#  'Comfort Food',
#  'Event Planning & Services',
#  'Hotels & Travel',
#  'Hotels',
#  'Venues & Event Spaces',
#  'Beauty & Spas',
#  'Hair Salons',
#  'Sandwiches',
#  'Chicken Wings',
#  'Restaurants',
#  'Donuts',
#  'Food',
#  'Home Services',
#  'Windows Installation',
#  'Thai',
#  'Vietnamese',
#  'Chinese',
#  'Restaurants',
#  'Shipping Centers',
#  'Notaries',
#  'Local Services',
#  'Printing Services',
#  'Mailbox Centers',
#  'Beauty & Spas',
#  'Eyelash Service',
#  'Skin Care',
#  'Tanning',
#  'Restaurants',
#  'Sandwiches',
#  'Restaurants',
#  'Acai Bowls',
#  'Vegan',
#  'Organic Stores',
#  'Vegetarian',
#  'Food',
#  'Juice Bars & Smoothies',
#  'Pet Services',
#  'Pets',
#  'Pet Training',
#  'Restaurants',
#  'Salad',
#  'Pakistani',
#  'Indian',
#  'Cocktail Bars',
#  'Food',
#  'Food Delivery Services',
#  'Soup',
#  'Halal',
#  'Bars',
#  'Nightlife',
#  'Street Vendors',
#  'Food',
#  'Food Trucks',
#  'Greek',
#  'Food Stands',
#  'Restaurants',
#  'Mediterranean',
#  'Local Flavor',
#  'Public Art',
#  'Museums',
#  'Nightlife',
#  'Arts & Entertainment',
#  'Music Venues',
#  'Education',
#  'Preschools',
#  'Local Services',
#  'Child Care & Day Care',
#  'Elementary Schools',
#  'Massage',
#  'Beauty & Spas',
#  'Convenience Stores',
#  'Food',
#  'Grocery',
#  'Coffee & Tea',
#  'Beer',
#  'Wine & Spirits',
#  'Auto Repair',
#  'Automotive',
#  'Car Wash',
#  'Automotive',
#  'Animal Shelters',
#  'Pet Adoption',
#  'Pets',
#  'Salad',
#  'Hot Dogs',
#  'Burgers',
#  'Restaurants',
#  'American (Traditional)',
#  'Fast Food',
#  'Nightlife',
#  'Pubs',
#  'American (Traditional)',
#  'Restaurants',
#  'Bars',
#  'Flooring',
#  'Refinishing Services',
#  'Home Services',
#  'Italian',
#  'Restaurants',
#  'Steakhouses',
#  'Tires',
#  'Automotive',
#  'Auto Repair',
#  'Oil Change Stations',
#  'Auto Detailing',
#  'Car Wash',
#  'Restaurants',
#  'Mexican',
#  'American (Traditional)',
#  'Electronics',
#  'Musical Instruments & Teachers',
#  'Shopping',
#  'Churches',
#  'Religious Organizations',
#  'Historical Tours',
#  'Tours',
#  'Hotels & Travel',
#  'Food Tours',
#  'Walking Tours',
#  'Restaurants',
#  'Mexican',
#  'Pizza',
#  'Fast Food',
#  'Gluten-Free',
#  'Restaurants',
#  'Salad',
#  'Local Services',
#  'Community Service/Non-Profit',
#  'Health & Medical',
#  'Doctors',
#  'Family Practice',
#  'Medical Centers',
#  'Counseling & Mental Health',
#  'Restaurants',
#  'Burgers',
#  'Shopping',
#  'Home Decor',
#  'Flooring',
#  'Home Services',
#  'Kitchen & Bath',
#  'Home & Garden',
#  'Building Supplies',
#  'Interior Design',
#  'Fashion',
#  'Discount Store',
#  'Sporting Goods',
#  'Military Surplus',
#  'Outdoor Gear',
#  'Shopping',
#  'Hobby Shops',
#  'Uniforms',
#  'Food',
#  'Coffee & Tea',
#  'Bakeries',
#  'Restaurants',
#  'Cafes',
#  'Restaurants',
#  'American (New)',
#  'Breakfast & Brunch',
#  'Burgers',
#  'Home Services',
#  'Keys & Locksmiths',
#  'Barbeque',
#  'Restaurants',
#  'Hot Dogs',
#  'Doctors',
#  'Health & Medical',
#  'Urgent Care',
#  'Walk-in Clinics',
#  'Medical Centers',
#  'Family Practice',
#  'Event Planning & Services',
#  'Restaurants',
#  'Empanadas',
#  'Caterers',
#  'Food',
#  'Desserts',
#  'Comfort Food',
#  'American (Traditional)',
#  'Food Trucks',
#  'American (New)',
#  'Restaurants',
#  'Active Life',
#  'Parks',
#  'Dog Parks',
#  'Restaurants',
#  'Italian',
#  'Nightlife',
#  'Southern',
#  'Bars',
#  'Breakfast & Brunch',
#  'Pizza',
#  'Food',
#  'Wholesalers',
#  'Coffee Roasteries',
#  'Professional Services',
#  'Coffee & Tea',
#  'Barbers',
#  'Education',
#  'Hair Salons',
#  'Cosmetology Schools',
#  'Specialty Schools',
#  'Beauty & Spas',
#  'Health & Medical',
#  'Dermatologists',
#  'Doctors',
#  'Mexican',
#  'Beer Bar',
#  'Bars',
#  'Sports Bars',
#  'Nightlife',
#  'Restaurants',
#  'Tacos',
#  'Active Life',
#  'Escape Games',
#  'Barbers',
#  'Beauty & Spas',
#  'Shopping',
#  'Vape Shops',
#  'Head Shops',
#  'Tobacco Shops',
#  'Korean',
#  'Restaurants',
#  'Self Storage',
#  'Local Services',
#  'Auto Parts & Supplies',
#  'Automotive',
#  'Pets',
#  'Pet Groomers',
#  'Pet Training',
#  'Pet Services',
#  'Pet Stores',
#  'Japanese',
#  'Restaurants',
#  'Sushi Bars',
#  'Chinese',
#  'Bars',
#  'Nightlife',
#  'Pubs',
#  'Shopping',
#  'Hair Salons',
#  'Professional Services',
#  'Beauty & Spas',
#  'Cosmetics & Beauty Supply',
#  'Beauty & Spas',
#  'Shopping',
#  'Cosmetics & Beauty Supply',
#  'Skin Care',
#  'Masonry/Concrete',
#  'Gardeners',
#  'Tree Services',
#  'Landscape Architects',
#  'Landscaping',
#  'Irrigation',
#  ...]

# %%
len(set(all_categories))
# Out:
# 1270

# %%
def check_categories(categories):
    """Return all food related categories"""
    try:
        return 'Restaurants' in categories.split(', ')
    except Exception:
        return False

filtered_business = business_df[business_df['categories'].apply(check_categories)]
len(filtered_business)
# Out:
# 30918

# %%
# only keep open businesses
filtered_business = filtered_business[filtered_business['is_open'] == 1]
len(filtered_business)
# Out:
# 29835

# %%
review_df = pd.read_json(review_path, lines=True)
review_df.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  Z6-2rrZvRnDcXpBiqhsk9A  pk3SPF_Ip1t65E3G9xFoKA  -e8RwknT5szoLk9uBZjzcw
# 1  C08Oi6p84SfNq_fh4GPKEQ  kk4GynEiF13My49uJ3hP7w  XYjlZTXifIjpAbPW33tCXw
# 2  1skKNG9rGSArmPXfvlcy6Q  DDpOQU-_tXEdHsoJN-REOg  bSJczuohHVko33UT82hnfA
# 3  oabif-hAnvLWOmSc4HCATQ  s4Cd9whJ8_g_p4iABq4hyQ  7UbXvL4SnVEDtx8oJbbuhw
# 4  mGW-EduqWdKsdHYVj8vSag  WXVo7Ff1NQPE71dnb0pK-A  UuRZpgZsHX7PyykHV3wbZg
#
#    stars  useful  funny  cool  \
# 0      5       1      0     0
# 1      5       0      0     0
# 2      2       0      0     0
# 3      2       0      1     0
# 4      5       0      0     0
#
#                                                 text                date
# 0  Had a great time tasting for my moms birthday.... 2021-03-01 00:00:43
# 1  Best place for ice cream on the go. Very covid... 2021-03-01 00:00:52
# 2  I went to blaze yesterday around this same tim... 2021-03-01 00:01:08
# 3  The gas is cheap, that's about it.  The servic... 2021-03-01 00:01:25
# 4  It was pretty late by the time I went in so th... 2021-03-01 00:01:41

# %%
filtered_reviews = pd.merge(review_df, users_df, on='user_id', how='inner')
filtered_reviews = pd.merge(filtered_reviews, filtered_business, on='business_id', how='inner')

# %%
print(len(filtered_reviews))
filtered_reviews.head()
# Out:
# 366252
#                 review_id                 user_id             business_id  \
# 0  1skKNG9rGSArmPXfvlcy6Q  DDpOQU-_tXEdHsoJN-REOg  bSJczuohHVko33UT82hnfA
# 1  mGW-EduqWdKsdHYVj8vSag  WXVo7Ff1NQPE71dnb0pK-A  UuRZpgZsHX7PyykHV3wbZg
# 2  fpFl0aaBvH-ODbFlG8Nqew  kk4GynEiF13My49uJ3hP7w  3Z4rhPFO6XWJRQipEIZCWA
# 3  d0BNtceSzXS34hMhXKzhJw  9lxeey8azLxu_DhcsrCO2Q  aRb_ToTRcHa9BICLLj8n-A
# 4  GEsSANWisPzNnR7MwSRLOA  x2PV9PpcRbJm74a9mb07ug  q7rBuON2WEIhdfz-AIYFFg
#
#    stars  useful_x  funny_x  cool_x  \
# 0      2         0        0       0
# 1      5         0        0       0
# 2      3         0        0       0
# 3      4         0        0       0
# 4      5         1        0       1
#
#                                                 text                date  \
# 0  I went to blaze yesterday around this same tim... 2021-03-01 00:01:08
# 1  It was pretty late by the time I went in so th... 2021-03-01 00:01:41
# 2  Always been a place with great atmosphere and ... 2021-03-01 00:02:54
# 3  This is becoming our go to takeout restaurant.... 2021-03-01 00:03:06
# 4  Tryed a new restaurant tonight! Mediterranean ... 2021-03-01 00:03:53
#
#   user_name  ...  state postal_code   latitude   longitude  rating  \
# 0     Malik  ...     LA       70113  29.948395  -90.075281     4.0
# 1     Sarah  ...     CA       93101  34.425720 -119.705241     4.0
# 2       Joe  ...     FL       34698  28.011587  -82.788281     3.5
# 3     David  ...     PA       19090  40.152561  -75.137371     4.5
# 4     Nancy  ...     MO       63303  38.789061  -90.549623     5.0
#
#   business_review_count is_open  \
# 0                   302       1
# 1                   761       1
# 2                   806       1
# 3                   174       1
# 4                   123       1
#
#                                           attributes  \
# 0  {'Ambience': '{'romantic': False, 'intimate': ...
# 1  {'BusinessParking': '{'garage': False, 'street...
# 2  {'RestaurantsReservations': 'True', 'GoodForKi...
# 3  {'RestaurantsPriceRange2': '2', 'RestaurantsTa...
# 4  {'BikeParking': 'True', 'BYOB': 'False', 'Rest...
#
#                                           categories  \
# 0  Pizza, Fast Food, Gluten-Free, Restaurants, Salad
# 1  Bakeries, Cafes, Coffee & Tea, Food, Desserts,...
# 2  Mexican, Restaurants, Desserts, Vegetarian, Fo...
# 3                            Restaurants, Vietnamese
# 4         Mediterranean, Restaurants, Middle Eastern
#
#                                                hours
# 0  {'Monday': '0:0-0:0', 'Tuesday': '11:0-22:0', ...
# 1  {'Monday': '8:0-16:0', 'Tuesday': '8:0-16:0', ...
# 2  {'Tuesday': '11:0-21:30', 'Wednesday': '11:0-2...
# 3  {'Monday': '11:0-19:0', 'Wednesday': '11:0-20:...
# 4  {'Tuesday': '10:0-20:0', 'Wednesday': '15:0-20...
#
# [5 rows x 43 columns]

# %%
filtered_reviews.columns
# Out:
# Index(['review_id', 'user_id', 'business_id', 'stars', 'useful_x', 'funny_x',
#        'cool_x', 'text', 'date', 'user_name', 'user_review_count',
#        'yelping_since', 'useful_y', 'funny_y', 'cool_y', 'elite', 'friends',
#        'fans', 'average_stars', 'compliment_hot', 'compliment_more',
#        'compliment_profile', 'compliment_cute', 'compliment_list',
#        'compliment_note', 'compliment_plain', 'compliment_cool',
#        'compliment_funny', 'compliment_writer', 'compliment_photos',
#        'business_name', 'address', 'city', 'state', 'postal_code', 'latitude',
#        'longitude', 'rating', 'business_review_count', 'is_open', 'attributes',
#        'categories', 'hours'],
#       dtype='object')

# %%
filtered_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366252 entries, 0 to 366251
# Data columns (total 43 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   review_id              366252 non-null  object
#  1   user_id                366252 non-null  object
#  2   business_id            366252 non-null  object
#  3   stars                  366252 non-null  int64
#  4   useful_x               366252 non-null  int64
#  5   funny_x                366252 non-null  int64
#  6   cool_x                 366252 non-null  int64
#  7   text                   366252 non-null  object
#  8   date                   366252 non-null  datetime64[ns]
#  9   user_name              366252 non-null  object
#  10  user_review_count      366252 non-null  int64
#  11  yelping_since          366252 non-null  object
#  12  useful_y               366252 non-null  int64
#  13  funny_y                366252 non-null  int64
#  14  cool_y                 366252 non-null  int64
#  15  elite                  366252 non-null  object
#  16  friends                366252 non-null  object
#  17  fans                   366252 non-null  int64
#  18  average_stars          366252 non-null  float64
#  19  compliment_hot         366252 non-null  int64
#  20  compliment_more        366252 non-null  int64
#  21  compliment_profile     366252 non-null  int64
#  22  compliment_cute        366252 non-null  int64
#  23  compliment_list        366252 non-null  int64
#  24  compliment_note        366252 non-null  int64
#  25  compliment_plain       366252 non-null  int64
#  26  compliment_cool        366252 non-null  int64
#  27  compliment_funny       366252 non-null  int64
#  28  compliment_writer      366252 non-null  int64
#  29  compliment_photos      366252 non-null  int64
#  30  business_name          366252 non-null  object
#  31  address                366252 non-null  object
#  32  city                   366252 non-null  object
#  33  state                  366252 non-null  object
#  34  postal_code            366252 non-null  object
#  35  latitude               366252 non-null  float64
#  36  longitude              366252 non-null  float64
#  37  rating                 366252 non-null  float64
#  38  business_review_count  366252 non-null  int64
#  39  is_open                366252 non-null  int64
#  40  attributes             364065 non-null  object
#  41  categories             366252 non-null  object
#  42  hours                  357572 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(22), object(16)
# memory usage: 120.2+ MB

# %%
photos_df = pd.read_json(photos_path, lines=True)
photos_df.head()
# Out:
#                  photo_id             business_id  \
# 0  zsvj7vloL4L5jhYyPIuVwg  Nk-SJhPlDBkAZvfsADtccA
# 1  HCUdRJHHm_e0OCTlZetGLg  yVZtL5MmrpiivyCIrVkGgA
# 2  vkr8T0scuJmGVvN2HJelEA  _ab50qdWOk0DdB6XOrBitw
# 3  pve7D6NUrafHW3EAORubyw  SZU9c8V2GuREDN5KgyHFJw
# 4  H52Er-uBg6rNrHcReWTD2w  Gzur0f0XMkrVxIwYJvOt2g
#
#                                              caption    label
# 0  Nice rock artwork everywhere and craploads of ...   inside
# 1                                                     outside
# 2                                     oyster shooter    drink
# 3                                      Shrimp scampi     food
# 4                                                        food

# %%
from sklearn.preprocessing import LabelEncoder

# Encode user and business ids using LabelEncoder   
le_user = LabelEncoder()
le_business = LabelEncoder()
filtered_reviews['user_id_enc'] = le_user.fit_transform(filtered_reviews['user_id'])
filtered_reviews['business_id_enc'] = le_business.fit_transform(filtered_reviews['business_id'])

# %%
filtered_reviews.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  1skKNG9rGSArmPXfvlcy6Q  DDpOQU-_tXEdHsoJN-REOg  bSJczuohHVko33UT82hnfA
# 1  mGW-EduqWdKsdHYVj8vSag  WXVo7Ff1NQPE71dnb0pK-A  UuRZpgZsHX7PyykHV3wbZg
# 2  fpFl0aaBvH-ODbFlG8Nqew  kk4GynEiF13My49uJ3hP7w  3Z4rhPFO6XWJRQipEIZCWA
# 3  d0BNtceSzXS34hMhXKzhJw  9lxeey8azLxu_DhcsrCO2Q  aRb_ToTRcHa9BICLLj8n-A
# 4  GEsSANWisPzNnR7MwSRLOA  x2PV9PpcRbJm74a9mb07ug  q7rBuON2WEIhdfz-AIYFFg
#
#    stars  useful_x  funny_x  cool_x  \
# 0      2         0        0       0
# 1      5         0        0       0
# 2      3         0        0       0
# 3      4         0        0       0
# 4      5         1        0       1
#
#                                                 text                date  \
# 0  I went to blaze yesterday around this same tim... 2021-03-01 00:01:08
# 1  It was pretty late by the time I went in so th... 2021-03-01 00:01:41
# 2  Always been a place with great atmosphere and ... 2021-03-01 00:02:54
# 3  This is becoming our go to takeout restaurant.... 2021-03-01 00:03:06
# 4  Tryed a new restaurant tonight! Mediterranean ... 2021-03-01 00:03:53
#
#   user_name  ...   latitude   longitude  rating  business_review_count  \
# 0     Malik  ...  29.948395  -90.075281     4.0                    302
# 1     Sarah  ...  34.425720 -119.705241     4.0                    761
# 2       Joe  ...  28.011587  -82.788281     3.5                    806
# 3     David  ...  40.152561  -75.137371     4.5                    174
# 4     Nancy  ...  38.789061  -90.549623     5.0                    123
#
#    is_open                                         attributes  \
# 0        1  {'Ambience': '{'romantic': False, 'intimate': ...
# 1        1  {'BusinessParking': '{'garage': False, 'street...
# 2        1  {'RestaurantsReservations': 'True', 'GoodForKi...
# 3        1  {'RestaurantsPriceRange2': '2', 'RestaurantsTa...
# 4        1  {'BikeParking': 'True', 'BYOB': 'False', 'Rest...
#
#                                           categories  \
# 0  Pizza, Fast Food, Gluten-Free, Restaurants, Salad
# 1  Bakeries, Cafes, Coffee & Tea, Food, Desserts,...
# 2  Mexican, Restaurants, Desserts, Vegetarian, Fo...
# 3                            Restaurants, Vietnamese
# 4         Mediterranean, Restaurants, Middle Eastern
#
#                                                hours  user_id_enc  \
# 0  {'Monday': '0:0-0:0', 'Tuesday': '11:0-22:0', ...        43324
# 1  {'Monday': '8:0-16:0', 'Tuesday': '8:0-16:0', ...       101817
# 2  {'Tuesday': '11:0-21:30', 'Wednesday': '11:0-2...       148081
# 3  {'Monday': '11:0-19:0', 'Wednesday': '11:0-20:...        32871
# 4  {'Tuesday': '10:0-20:0', 'Wednesday': '15:0-20...       185620
#
#    business_id_enc
# 0            18402
# 1            14941
# 2             2234
# 3            17949
# 4            25283
#
# [5 rows x 45 columns]
